# %% [markdown]
# # 종목 가져오기

# %% [markdown]
# 패키지 가져오기 및 headers 선언

# %%
import requests # HTTP 호출 패키지
import json # json 형식의 파일 관련 패키지
import pandas as pd # 데이터 분석 및 연산 패키지

# %%
# headers 선언
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest'
}

# %% [markdown]
# 가져올 데이터 속성 값 p_data에 할당

# %%
# payload 데이터 설정 (데이터 속성)
p_data = {
    'bld': 'dbms/MDC/STAT/standard/MDCSTAT00601', # 화면번호
    'tboxindIdx_finder_equidx0_0': '코스피', # 지수명(한글)
    'indIdx': '1', # 지수코드1
    'indIdx2': '001', # 지수코드2
    'codeNmindIdx_finder_equidx0_0': '코스피', # 지수명(한글)
    'param1indIdx_finder_equidx0_0': '', # (blank)
    'trdDd': '20220503', # 조회 날짜
    'money': '3', # 금액 단위
    'csvxls_isNo': 'false' # (false)
}

# %% [markdown]
# * 데이터의 URL을 설정한 뒤, HTTP 서버에 데이터를 요청
# * 요청한 데이터를 json 형식으로 변환해 html_json에 할당해줌

# %%
# 데이터의 url 설정
# header-general-Request URL 확인
url = 'http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd'

# %%
# HTTP 서버에 데이터 요청
# header-general-Request Method 확인
res = requests.post(url, headers=headers, data=p_data)

# %%
# 요청한 데이터를 json 형식으로 html_json에 할당
html_json = json.loads(res.content)

# %%
html_json
# Out:
# {'output': [{'ISU_SRT_CD': '005930',
#    'ISU_ABBRV': '삼성전자',
#    'TDD_CLSPRC': '67,500',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '200',
#    'FLUC_RT': '0.30',
#    'MKTCAP': '402,960,322,125,000'},
#   {'ISU_SRT_CD': '373220',
#    'ISU_ABBRV': 'LG에너지솔루션',
#    'TDD_CLSPRC': '407,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-0.24',
#    'MKTCAP': '95,355,000,000,000'},
#   {'ISU_SRT_CD': '000660',
#    'ISU_ABBRV': 'SK하이닉스',
#    'TDD_CLSPRC': '110,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-500',
#    'FLUC_RT': '-0.45',
#    'MKTCAP': '80,080,260,150,000'},
#   {'ISU_SRT_CD': '207940',
#    'ISU_ABBRV': '삼성바이오로직스',
#    'TDD_CLSPRC': '832,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-6,000',
#    'FLUC_RT': '-0.72',
#    'MKTCAP': '59,216,768,000,000'},
#   {'ISU_SRT_CD': '035420',
#    'ISU_ABBRV': 'NAVER',
#    'TDD_CLSPRC': '282,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,000',
#    'FLUC_RT': '0.36',
#    'MKTCAP': '46,261,841,970,000'},
#   {'ISU_SRT_CD': '006400',
#    'ISU_ABBRV': '삼성SDI',
#    'TDD_CLSPRC': '624,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '13,000',
#    'FLUC_RT': '2.13',
#    'MKTCAP': '42,909,066,720,000'},
#   {'ISU_SRT_CD': '035720',
#    'ISU_ABBRV': '카카오',
#    'TDD_CLSPRC': '88,500',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,200',
#    'FLUC_RT': '1.37',
#    'MKTCAP': '39,494,930,931,000'},
#   {'ISU_SRT_CD': '005380',
#    'ISU_ABBRV': '현대차',
#    'TDD_CLSPRC': '183,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-3,500',
#    'FLUC_RT': '-1.87',
#    'MKTCAP': '39,208,112,314,500'},
#   {'ISU_SRT_CD': '051910',
#    'ISU_ABBRV': 'LG화학',
#    'TDD_CLSPRC': '517,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-9,000',
#    'FLUC_RT': '-1.71',
#    'MKTCAP': '36,496,241,331,000'},
#   {'ISU_SRT_CD': '000270',
#    'ISU_ABBRV': '기아',
#    'TDD_CLSPRC': '83,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-900',
#    'FLUC_RT': '-1.07',
#    'MKTCAP': '33,847,839,474,500'},
#   {'ISU_SRT_CD': '005490',
#    'ISU_ABBRV': 'POSCO홀딩스',
#    'TDD_CLSPRC': '289,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-4,000',
#    'FLUC_RT': '-1.37',
#    'MKTCAP': '25,196,995,315,000'},
#   {'ISU_SRT_CD': '068270',
#    'ISU_ABBRV': '셀트리온',
#    'TDD_CLSPRC': '172,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-0.58',
#    'MKTCAP': '24,198,337,720,000'},
#   {'ISU_SRT_CD': '105560',
#    'ISU_ABBRV': 'KB금융',
#    'TDD_CLSPRC': '58,600',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '300',
#    'FLUC_RT': '0.51',
#    'MKTCAP': '24,163,856,148,400'},
#   {'ISU_SRT_CD': '055550',
#    'ISU_ABBRV': '신한지주',
#    'TDD_CLSPRC': '41,650',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.12',
#    'MKTCAP': '21,516,371,424,100'},
#   {'ISU_SRT_CD': '028260',
#    'ISU_ABBRV': '삼성물산',
#    'TDD_CLSPRC': '115,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-2,500',
#    'FLUC_RT': '-2.12',
#    'MKTCAP': '21,585,457,855,500'},
#   {'ISU_SRT_CD': '012330',
#    'ISU_ABBRV': '현대모비스',
#    'TDD_CLSPRC': '206,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-2,000',
#    'FLUC_RT': '-0.96',
#    'MKTCAP': '19,529,343,911,000'},
#   {'ISU_SRT_CD': '323410',
#    'ISU_ABBRV': '카카오뱅크',
#    'TDD_CLSPRC': '41,250',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '150',
#    'FLUC_RT': '0.36',
#    'MKTCAP': '19,643,103,026,250'},
#   {'ISU_SRT_CD': '034730',
#    'ISU_ABBRV': 'SK',
#    'TDD_CLSPRC': '261,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-8,000',
#    'FLUC_RT': '-2.97',
#    'MKTCAP': '19,352,974,869,000'},
#   {'ISU_SRT_CD': '066570',
#    'ISU_ABBRV': 'LG전자',
#    'TDD_CLSPRC': '115,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-0.86',
#    'MKTCAP': '18,901,322,517,000'},
#   {'ISU_SRT_CD': '096770',
#    'ISU_ABBRV': 'SK이노베이션',
#    'TDD_CLSPRC': '202,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-0.49',
#    'MKTCAP': '18,724,276,710,000'},
#   {'ISU_SRT_CD': '377300',
#    'ISU_ABBRV': '카카오페이',
#    'TDD_CLSPRC': '108,500',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '500',
#    'FLUC_RT': '0.46',
#    'MKTCAP': '14,369,597,973,500'},
#   {'ISU_SRT_CD': '015760',
#    'ISU_ABBRV': '한국전력',
#    'TDD_CLSPRC': '22,150',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-300',
#    'FLUC_RT': '-1.34',
#    'MKTCAP': '14,219,504,305,550'},
#   {'ISU_SRT_CD': '011200',
#    'ISU_ABBRV': 'HMM',
#    'TDD_CLSPRC': '28,900',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.17',
#    'MKTCAP': '14,133,241,434,400'},
#   {'ISU_SRT_CD': '086790',
#    'ISU_ABBRV': '하나금융지주',
#    'TDD_CLSPRC': '46,250',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-350',
#    'FLUC_RT': '-0.75',
#    'MKTCAP': '13,886,195,367,500'},
#   {'ISU_SRT_CD': '051900',
#    'ISU_ABBRV': 'LG생활건강',
#    'TDD_CLSPRC': '876,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-35,000',
#    'FLUC_RT': '-3.84',
#    'MKTCAP': '13,681,540,572,000'},
#   {'ISU_SRT_CD': '034020',
#    'ISU_ABBRV': '두산에너빌리티',
#    'TDD_CLSPRC': '20,800',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '350',
#    'FLUC_RT': '1.71',
#    'MKTCAP': '13,147,086,326,400'},
#   {'ISU_SRT_CD': '032830',
#    'ISU_ABBRV': '삼성생명',
#    'TDD_CLSPRC': '64,300',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-500',
#    'FLUC_RT': '-0.77',
#    'MKTCAP': '12,860,000,000,000'},
#   {'ISU_SRT_CD': '017670',
#    'ISU_ABBRV': 'SK텔레콤',
#    'TDD_CLSPRC': '57,800',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '800',
#    'FLUC_RT': '1.40',
#    'MKTCAP': '12,648,555,723,200'},
#   {'ISU_SRT_CD': '259960',
#    'ISU_ABBRV': '크래프톤',
#    'TDD_CLSPRC': '256,500',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '5,000',
#    'FLUC_RT': '1.99',
#    'MKTCAP': '12,586,979,542,500'},
#   {'ISU_SRT_CD': '009150',
#    'ISU_ABBRV': '삼성전기',
#    'TDD_CLSPRC': '166,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-2,000',
#    'FLUC_RT': '-1.19',
#    'MKTCAP': '12,436,500,384,000'},
#   {'ISU_SRT_CD': '329180',
#    'ISU_ABBRV': '현대중공업',
#    'TDD_CLSPRC': '137,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-2,500',
#    'FLUC_RT': '-1.79',
#    'MKTCAP': '12,206,303,450,000'},
#   {'ISU_SRT_CD': '010950',
#    'ISU_ABBRV': 'S-Oil',
#    'TDD_CLSPRC': '106,000',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '11,933,775,952,000'},
#   {'ISU_SRT_CD': '003550',
#    'ISU_ABBRV': 'LG',
#    'TDD_CLSPRC': '73,600',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-200',
#    'FLUC_RT': '-0.27',
#    'MKTCAP': '11,577,353,084,800'},
#   {'ISU_SRT_CD': '033780',
#    'ISU_ABBRV': 'KT&G',
#    'TDD_CLSPRC': '82,500',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '11,326,631,002,500'},
#   {'ISU_SRT_CD': '018260',
#    'ISU_ABBRV': '삼성에스디에스',
#    'TDD_CLSPRC': '147,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,500',
#    'FLUC_RT': '-1.01',
#    'MKTCAP': '11,413,225,500,000'},
#   {'ISU_SRT_CD': '316140',
#    'ISU_ABBRV': '우리금융지주',
#    'TDD_CLSPRC': '15,200',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '250',
#    'FLUC_RT': '1.67',
#    'MKTCAP': '11,066,520,344,800'},
#   {'ISU_SRT_CD': '010130',
#    'ISU_ABBRV': '고려아연',
#    'TDD_CLSPRC': '568,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-9,000',
#    'FLUC_RT': '-1.56',
#    'MKTCAP': '10,718,160,000,000'},
#   {'ISU_SRT_CD': '352820',
#    'ISU_ABBRV': '하이브',
#    'TDD_CLSPRC': '253,500',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,000',
#    'FLUC_RT': '0.40',
#    'MKTCAP': '10,483,083,604,500'},
#   {'ISU_SRT_CD': '003670',
#    'ISU_ABBRV': '포스코케미칼',
#    'TDD_CLSPRC': '134,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-0.74',
#    'MKTCAP': '10,380,071,480,000'},
#   {'ISU_SRT_CD': '003490',
#    'ISU_ABBRV': '대한항공',
#    'TDD_CLSPRC': '30,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '50',
#    'FLUC_RT': '0.17',
#    'MKTCAP': '10,434,624,750,000'},
#   {'ISU_SRT_CD': '090430',
#    'ISU_ABBRV': '아모레퍼시픽',
#    'TDD_CLSPRC': '172,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-6,500',
#    'FLUC_RT': '-3.63',
#    'MKTCAP': '10,090,000,927,500'},
#   {'ISU_SRT_CD': '302440',
#    'ISU_ABBRV': 'SK바이오사이언스',
#    'TDD_CLSPRC': '133,500',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,000',
#    'FLUC_RT': '0.75',
#    'MKTCAP': '10,250,670,141,000'},
#   {'ISU_SRT_CD': '000810',
#    'ISU_ABBRV': '삼성화재',
#    'TDD_CLSPRC': '204,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-2,000',
#    'FLUC_RT': '-0.97',
#    'MKTCAP': '9,664,466,748,000'},
#   {'ISU_SRT_CD': '036570',
#    'ISU_ABBRV': '엔씨소프트',
#    'TDD_CLSPRC': '432,500',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '7,500',
#    'FLUC_RT': '1.76',
#    'MKTCAP': '9,495,114,515,000'},
#   {'ISU_SRT_CD': '030200',
#    'ISU_ABBRV': 'KT',
#    'TDD_CLSPRC': '35,200',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-300',
#    'FLUC_RT': '-0.85',
#    'MKTCAP': '9,191,135,641,600'},
#   {'ISU_SRT_CD': '361610',
#    'ISU_ABBRV': 'SK아이이테크놀로지',
#    'TDD_CLSPRC': '125,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,500',
#    'FLUC_RT': '1.21',
#    'MKTCAP': '8,912,199,000,000'},
#   {'ISU_SRT_CD': '024110',
#    'ISU_ABBRV': '기업은행',
#    'TDD_CLSPRC': '11,350',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '100',
#    'FLUC_RT': '0.89',
#    'MKTCAP': '8,447,811,662,450'},
#   {'ISU_SRT_CD': '011070',
#    'ISU_ABBRV': 'LG이노텍',
#    'TDD_CLSPRC': '344,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-2,000',
#    'FLUC_RT': '-0.58',
#    'MKTCAP': '8,141,484,808,000'},
#   {'ISU_SRT_CD': '251270',
#    'ISU_ABBRV': '넷마블',
#    'TDD_CLSPRC': '93,100',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '100',
#    'FLUC_RT': '0.11',
#    'MKTCAP': '8,002,271,036,200'},
#   {'ISU_SRT_CD': '086280',
#    'ISU_ABBRV': '현대글로비스',
#    'TDD_CLSPRC': '205,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-5,000',
#    'FLUC_RT': '-2.38',
#    'MKTCAP': '7,706,250,000,000'},
#   {'ISU_SRT_CD': '402340',
#    'ISU_ABBRV': 'SK스퀘어',
#    'TDD_CLSPRC': '51,400',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '7,271,433,149,400'},
#   {'ISU_SRT_CD': '326030',
#    'ISU_ABBRV': 'SK바이오팜',
#    'TDD_CLSPRC': '91,600',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,500',
#    'FLUC_RT': '-1.61',
#    'MKTCAP': '7,173,493,700,000'},
#   {'ISU_SRT_CD': '011170',
#    'ISU_ABBRV': '롯데케미칼',
#    'TDD_CLSPRC': '197,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-0.51',
#    'MKTCAP': '6,752,257,543,000'},
#   {'ISU_SRT_CD': '009540',
#    'ISU_ABBRV': '한국조선해양',
#    'TDD_CLSPRC': '90,200',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,500',
#    'FLUC_RT': '-1.64',
#    'MKTCAP': '6,383,735,063,200'},
#   {'ISU_SRT_CD': '018880',
#    'ISU_ABBRV': '한온시스템',
#    'TDD_CLSPRC': '11,300',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '6,031,940,000,000'},
#   {'ISU_SRT_CD': '009830',
#    'ISU_ABBRV': '한화솔루션',
#    'TDD_CLSPRC': '31,850',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.16',
#    'MKTCAP': '6,092,220,129,450'},
#   {'ISU_SRT_CD': '034220',
#    'ISU_ABBRV': 'LG디스플레이',
#    'TDD_CLSPRC': '17,300',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '600',
#    'FLUC_RT': '3.59',
#    'MKTCAP': '6,190,211,610,000'},
#   {'ISU_SRT_CD': '032640',
#    'ISU_ABBRV': 'LG유플러스',
#    'TDD_CLSPRC': '13,950',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '50',
#    'FLUC_RT': '0.36',
#    'MKTCAP': '6,090,728,485,950'},
#   {'ISU_SRT_CD': '011790',
#    'ISU_ABBRV': 'SKC',
#    'TDD_CLSPRC': '153,500',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '500',
#    'FLUC_RT': '0.33',
#    'MKTCAP': '5,812,783,743,000'},
#   {'ISU_SRT_CD': '097950',
#    'ISU_ABBRV': 'CJ제일제당',
#    'TDD_CLSPRC': '388,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-13,500',
#    'FLUC_RT': '-3.36',
#    'MKTCAP': '5,841,024,168,000'},
#   {'ISU_SRT_CD': '035250',
#    'ISU_ABBRV': '강원랜드',
#    'TDD_CLSPRC': '26,450',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-250',
#    'FLUC_RT': '-0.94',
#    'MKTCAP': '5,658,726,225,000'},
#   {'ISU_SRT_CD': '004020',
#    'ISU_ABBRV': '현대제철',
#    'TDD_CLSPRC': '43,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-550',
#    'FLUC_RT': '-1.25',
#    'MKTCAP': '5,804,891,647,500'},
#   {'ISU_SRT_CD': '088980',
#    'ISU_ABBRV': '맥쿼리인프라',
#    'TDD_CLSPRC': '14,200',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.35',
#    'MKTCAP': '5,748,806,767,400'},
#   {'ISU_SRT_CD': '383220',
#    'ISU_ABBRV': 'F&F',
#    'TDD_CLSPRC': '140,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-0.71',
#    'MKTCAP': '5,382,144,037,500'},
#   {'ISU_SRT_CD': '000060',
#    'ISU_ABBRV': '메리츠화재',
#    'TDD_CLSPRC': '43,950',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-400',
#    'FLUC_RT': '-0.90',
#    'MKTCAP': '5,301,468,750,000'},
#   {'ISU_SRT_CD': '010140',
#    'ISU_ABBRV': '삼성중공업',
#    'TDD_CLSPRC': '5,910',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-120',
#    'FLUC_RT': '-1.99',
#    'MKTCAP': '5,200,800,000,000'},
#   {'ISU_SRT_CD': '028050',
#    'ISU_ABBRV': '삼성엔지니어링',
#    'TDD_CLSPRC': '26,050',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.19',
#    'MKTCAP': '5,105,800,000,000'},
#   {'ISU_SRT_CD': '021240',
#    'ISU_ABBRV': '코웨이',
#    'TDD_CLSPRC': '69,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-2,800',
#    'FLUC_RT': '-3.87',
#    'MKTCAP': '5,129,073,520,500'},
#   {'ISU_SRT_CD': '137310',
#    'ISU_ABBRV': '에스디바이오센서',
#    'TDD_CLSPRC': '46,650',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '50',
#    'FLUC_RT': '0.11',
#    'MKTCAP': '4,817,608,617,450'},
#   {'ISU_SRT_CD': '000720',
#    'ISU_ABBRV': '현대건설',
#    'TDD_CLSPRC': '44,650',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-100',
#    'FLUC_RT': '-0.22',
#    'MKTCAP': '4,972,034,907,250'},
#   {'ISU_SRT_CD': '006800',
#    'ISU_ABBRV': '미래에셋증권',
#    'TDD_CLSPRC': '7,970',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-90',
#    'FLUC_RT': '-1.12',
#    'MKTCAP': '4,904,071,771,760'},
#   {'ISU_SRT_CD': '138040',
#    'ISU_ABBRV': '메리츠금융지주',
#    'TDD_CLSPRC': '37,050',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-2.63',
#    'MKTCAP': '4,855,450,442,700'},
#   {'ISU_SRT_CD': '267250',
#    'ISU_ABBRV': 'HD현대',
#    'TDD_CLSPRC': '58,300',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '200',
#    'FLUC_RT': '0.34',
#    'MKTCAP': '4,605,296,855,500'},
#   {'ISU_SRT_CD': '011780',
#    'ISU_ABBRV': '금호석유',
#    'TDD_CLSPRC': '154,500',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '4,680,707,898,000'},
#   {'ISU_SRT_CD': '005830',
#    'ISU_ABBRV': 'DB손해보험',
#    'TDD_CLSPRC': '65,400',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-600',
#    'FLUC_RT': '-0.91',
#    'MKTCAP': '4,630,320,000,000'},
#   {'ISU_SRT_CD': '047810',
#    'ISU_ABBRV': '한국항공우주',
#    'TDD_CLSPRC': '47,200',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '750',
#    'FLUC_RT': '1.61',
#    'MKTCAP': '4,600,825,050,400'},
#   {'ISU_SRT_CD': '000100',
#    'ISU_ABBRV': '유한양행',
#    'TDD_CLSPRC': '60,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-400',
#    'FLUC_RT': '-0.66',
#    'MKTCAP': '4,430,504,298,000'},
#   {'ISU_SRT_CD': '078930',
#    'ISU_ABBRV': 'GS',
#    'TDD_CLSPRC': '45,100',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '550',
#    'FLUC_RT': '1.23',
#    'MKTCAP': '4,190,483,547,800'},
#   {'ISU_SRT_CD': '008560',
#    'ISU_ABBRV': '메리츠증권',
#    'TDD_CLSPRC': '6,620',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-210',
#    'FLUC_RT': '-3.07',
#    'MKTCAP': '4,367,813,632,980'},
#   {'ISU_SRT_CD': '161390',
#    'ISU_ABBRV': '한국타이어앤테크놀로지',
#    'TDD_CLSPRC': '34,900',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-700',
#    'FLUC_RT': '-1.97',
#    'MKTCAP': '4,323,239,908,100'},
#   {'ISU_SRT_CD': '241560',
#    'ISU_ABBRV': '두산밥캣',
#    'TDD_CLSPRC': '41,200',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '100',
#    'FLUC_RT': '0.24',
#    'MKTCAP': '4,130,265,639,200'},
#   {'ISU_SRT_CD': '003410',
#    'ISU_ABBRV': '쌍용C&E',
#    'TDD_CLSPRC': '8,190',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.61',
#    'MKTCAP': '4,126,610,083,050'},
#   {'ISU_SRT_CD': '002790',
#    'ISU_ABBRV': '아모레G',
#    'TDD_CLSPRC': '49,300',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,500',
#    'FLUC_RT': '-2.95',
#    'MKTCAP': '4,065,188,274,000'},
#   {'ISU_SRT_CD': '020150',
#    'ISU_ABBRV': '일진머티리얼즈',
#    'TDD_CLSPRC': '88,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-700',
#    'FLUC_RT': '-0.79',
#    'MKTCAP': '4,057,753,480,000'},
#   {'ISU_SRT_CD': '307950',
#    'ISU_ABBRV': '현대오토에버',
#    'TDD_CLSPRC': '138,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-0.72',
#    'MKTCAP': '3,784,509,516,000'},
#   {'ISU_SRT_CD': '071050',
#    'ISU_ABBRV': '한국금융지주',
#    'TDD_CLSPRC': '71,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,000',
#    'FLUC_RT': '1.43',
#    'MKTCAP': '3,956,545,432,000'},
#   {'ISU_SRT_CD': '036460',
#    'ISU_ABBRV': '한국가스공사',
#    'TDD_CLSPRC': '41,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-500',
#    'FLUC_RT': '-1.20',
#    'MKTCAP': '3,784,833,000,000'},
#   {'ISU_SRT_CD': '029780',
#    'ISU_ABBRV': '삼성카드',
#    'TDD_CLSPRC': '33,250',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-0.45',
#    'MKTCAP': '3,852,308,125,750'},
#   {'ISU_SRT_CD': '180640',
#    'ISU_ABBRV': '한진칼',
#    'TDD_CLSPRC': '57,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-400',
#    'FLUC_RT': '-0.70',
#    'MKTCAP': '3,805,392,048,000'},
#   {'ISU_SRT_CD': '271560',
#    'ISU_ABBRV': '오리온',
#    'TDD_CLSPRC': '91,100',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-4,300',
#    'FLUC_RT': '-4.51',
#    'MKTCAP': '3,601,741,625,200'},
#   {'ISU_SRT_CD': '128940',
#    'ISU_ABBRV': '한미약품',
#    'TDD_CLSPRC': '302,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-7,500',
#    'FLUC_RT': '-2.42',
#    'MKTCAP': '3,726,186,227,500'},
#   {'ISU_SRT_CD': '006360',
#    'ISU_ABBRV': 'GS건설',
#    'TDD_CLSPRC': '41,900',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-400',
#    'FLUC_RT': '-0.95',
#    'MKTCAP': '3,585,864,431,000'},
#   {'ISU_SRT_CD': '028670',
#    'ISU_ABBRV': '팬오션',
#    'TDD_CLSPRC': '6,820',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-90',
#    'FLUC_RT': '-1.30',
#    'MKTCAP': '3,645,764,071,840'},
#   {'ISU_SRT_CD': '004990',
#    'ISU_ABBRV': '롯데지주',
#    'TDD_CLSPRC': '34,300',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '3,598,386,829,100'},
#   {'ISU_SRT_CD': '139480',
#    'ISU_ABBRV': '이마트',
#    'TDD_CLSPRC': '129,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-2,000',
#    'FLUC_RT': '-1.52',
#    'MKTCAP': '3,609,918,560,500'},
#   {'ISU_SRT_CD': '016360',
#    'ISU_ABBRV': '삼성증권',
#    'TDD_CLSPRC': '39,600',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-0.38',
#    'MKTCAP': '3,536,280,000,000'},
#   {'ISU_SRT_CD': '008930',
#    'ISU_ABBRV': '한미사이언스',
#    'TDD_CLSPRC': '49,050',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,650',
#    'FLUC_RT': '-3.25',
#    'MKTCAP': '3,365,991,700,200'},
#   {'ISU_SRT_CD': '005940',
#    'ISU_ABBRV': 'NH투자증권',
#    'TDD_CLSPRC': '10,650',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-1.39',
#    'MKTCAP': '3,532,242,058,650'},
#   {'ISU_SRT_CD': '282330',
#    'ISU_ABBRV': 'BGF리테일',
#    'TDD_CLSPRC': '187,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '5,000',
#    'FLUC_RT': '2.75',
#    'MKTCAP': '3,232,090,422,000'},
#   {'ISU_SRT_CD': '010620',
#    'ISU_ABBRV': '현대미포조선',
#    'TDD_CLSPRC': '81,800',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,200',
#    'FLUC_RT': '-1.45',
#    'MKTCAP': '3,267,267,788,200'},
#   {'ISU_SRT_CD': '008770',
#    'ISU_ABBRV': '호텔신라',
#    'TDD_CLSPRC': '80,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-500',
#    'FLUC_RT': '-0.62',
#    'MKTCAP': '3,159,473,740,500'},
#   {'ISU_SRT_CD': '272210',
#    'ISU_ABBRV': '한화시스템',
#    'TDD_CLSPRC': '15,850',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-200',
#    'FLUC_RT': '-1.25',
#    'MKTCAP': '2,994,372,315,650'},
#   {'ISU_SRT_CD': '030000',
#    'ISU_ABBRV': '제일기획',
#    'TDD_CLSPRC': '26,250',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '650',
#    'FLUC_RT': '2.54',
#    'MKTCAP': '3,019,832,156,250'},
#   {'ISU_SRT_CD': '002380',
#    'ISU_ABBRV': 'KCC',
#    'TDD_CLSPRC': '355,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '5,500',
#    'FLUC_RT': '1.57',
#    'MKTCAP': '3,154,697,205,000'},
#   {'ISU_SRT_CD': '007070',
#    'ISU_ABBRV': 'GS리테일',
#    'TDD_CLSPRC': '29,400',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-300',
#    'FLUC_RT': '-1.01',
#    'MKTCAP': '3,078,706,906,800'},
#   {'ISU_SRT_CD': '000990',
#    'ISU_ABBRV': 'DB하이텍',
#    'TDD_CLSPRC': '67,700',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '800',
#    'FLUC_RT': '1.20',
#    'MKTCAP': '3,005,784,407,600'},
#   {'ISU_SRT_CD': '047050',
#    'ISU_ABBRV': '포스코인터내셔널',
#    'TDD_CLSPRC': '24,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.20',
#    'MKTCAP': '3,022,691,150,500'},
#   {'ISU_SRT_CD': '047040',
#    'ISU_ABBRV': '대우건설',
#    'TDD_CLSPRC': '6,750',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-10',
#    'FLUC_RT': '-0.15',
#    'MKTCAP': '2,805,452,806,500'},
#   {'ISU_SRT_CD': '052690',
#    'ISU_ABBRV': '한전기술',
#    'TDD_CLSPRC': '75,800',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '2,300',
#    'FLUC_RT': '3.13',
#    'MKTCAP': '2,897,076,000,000'},
#   {'ISU_SRT_CD': '001450',
#    'ISU_ABBRV': '현대해상',
#    'TDD_CLSPRC': '31,350',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '150',
#    'FLUC_RT': '0.48',
#    'MKTCAP': '2,802,690,000,000'},
#   {'ISU_SRT_CD': '014680',
#    'ISU_ABBRV': '한솔케미칼',
#    'TDD_CLSPRC': '244,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,000',
#    'FLUC_RT': '0.41',
#    'MKTCAP': '2,765,787,580,000'},
#   {'ISU_SRT_CD': '000120',
#    'ISU_ABBRV': 'CJ대한통운',
#    'TDD_CLSPRC': '121,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,500',
#    'FLUC_RT': '-1.22',
#    'MKTCAP': '2,760,293,624,000'},
#   {'ISU_SRT_CD': '012450',
#    'ISU_ABBRV': '한화에어로스페이스',
#    'TDD_CLSPRC': '56,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,500',
#    'FLUC_RT': '2.75',
#    'MKTCAP': '2,835,280,000,000'},
#   {'ISU_SRT_CD': '138930',
#    'ISU_ABBRV': 'BNK금융지주',
#    'TDD_CLSPRC': '7,890',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '2,571,629,090,940'},
#   {'ISU_SRT_CD': '023530',
#    'ISU_ABBRV': '롯데쇼핑',
#    'TDD_CLSPRC': '94,300',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-200',
#    'FLUC_RT': '-0.21',
#    'MKTCAP': '2,667,629,596,500'},
#   {'ISU_SRT_CD': '026960',
#    'ISU_ABBRV': '동서',
#    'TDD_CLSPRC': '26,750',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-0.56',
#    'MKTCAP': '2,666,975,000,000'},
#   {'ISU_SRT_CD': '000080',
#    'ISU_ABBRV': '하이트진로',
#    'TDD_CLSPRC': '37,800',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '350',
#    'FLUC_RT': '0.93',
#    'MKTCAP': '2,651,050,495,800'},
#   {'ISU_SRT_CD': '010060',
#    'ISU_ABBRV': 'OCI',
#    'TDD_CLSPRC': '110,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '500',
#    'FLUC_RT': '0.46',
#    'MKTCAP': '2,623,430,810,000'},
#   {'ISU_SRT_CD': '012750',
#    'ISU_ABBRV': '에스원',
#    'TDD_CLSPRC': '68,700',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '2,610,543,528,600'},
#   {'ISU_SRT_CD': '042660',
#    'ISU_ABBRV': '대우조선해양',
#    'TDD_CLSPRC': '25,300',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-750',
#    'FLUC_RT': '-2.88',
#    'MKTCAP': '2,714,453,925,700'},
#   {'ISU_SRT_CD': '088350',
#    'ISU_ABBRV': '한화생명',
#    'TDD_CLSPRC': '2,875',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-15',
#    'FLUC_RT': '-0.52',
#    'MKTCAP': '2,497,023,750,000'},
#   {'ISU_SRT_CD': '112610',
#    'ISU_ABBRV': '씨에스윈드',
#    'TDD_CLSPRC': '57,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,100',
#    'FLUC_RT': '-1.88',
#    'MKTCAP': '2,424,855,672,500'},
#   {'ISU_SRT_CD': '004170',
#    'ISU_ABBRV': '신세계',
#    'TDD_CLSPRC': '246,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-500',
#    'FLUC_RT': '-0.20',
#    'MKTCAP': '2,421,914,526,000'},
#   {'ISU_SRT_CD': '039490',
#    'ISU_ABBRV': '키움증권',
#    'TDD_CLSPRC': '93,300',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '2,446,280,562,900'},
#   {'ISU_SRT_CD': '001040',
#    'ISU_ABBRV': 'CJ',
#    'TDD_CLSPRC': '85,100',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,900',
#    'FLUC_RT': '-2.18',
#    'MKTCAP': '2,482,962,529,800'},
#   {'ISU_SRT_CD': '204320',
#    'ISU_ABBRV': '만도',
#    'TDD_CLSPRC': '54,200',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-200',
#    'FLUC_RT': '-0.37',
#    'MKTCAP': '2,545,075,904,000'},
#   {'ISU_SRT_CD': '285130',
#    'ISU_ABBRV': 'SK케미칼',
#    'TDD_CLSPRC': '128,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-500',
#    'FLUC_RT': '-0.39',
#    'MKTCAP': '2,255,459,840,000'},
#   {'ISU_SRT_CD': '336260',
#    'ISU_ABBRV': '두산퓨얼셀',
#    'TDD_CLSPRC': '34,550',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '250',
#    'FLUC_RT': '0.73',
#    'MKTCAP': '2,262,808,233,300'},
#   {'ISU_SRT_CD': '336370',
#    'ISU_ABBRV': '솔루스첨단소재',
#    'TDD_CLSPRC': '71,900',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-800',
#    'FLUC_RT': '-1.10',
#    'MKTCAP': '2,199,403,600,200'},
#   {'ISU_SRT_CD': '001440',
#    'ISU_ABBRV': '대한전선',
#    'TDD_CLSPRC': '1,865',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-5',
#    'FLUC_RT': '-0.27',
#    'MKTCAP': '2,320,942,161,785'},
#   {'ISU_SRT_CD': '016380',
#    'ISU_ABBRV': 'KG스틸',
#    'TDD_CLSPRC': '23,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-600',
#    'FLUC_RT': '-2.54',
#    'MKTCAP': '2,300,204,631,000'},
#   {'ISU_SRT_CD': '006280',
#    'ISU_ABBRV': '녹십자',
#    'TDD_CLSPRC': '187,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-6,000',
#    'FLUC_RT': '-3.11',
#    'MKTCAP': '2,185,382,606,000'},
#   {'ISU_SRT_CD': '000880',
#    'ISU_ABBRV': '한화',
#    'TDD_CLSPRC': '29,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-100',
#    'FLUC_RT': '-0.34',
#    'MKTCAP': '2,211,282,682,500'},
#   {'ISU_SRT_CD': '375500',
#    'ISU_ABBRV': 'DL이앤씨',
#    'TDD_CLSPRC': '55,400',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-4,200',
#    'FLUC_RT': '-7.05',
#    'MKTCAP': '2,143,626,714,200'},
#   {'ISU_SRT_CD': '298050',
#    'ISU_ABBRV': '효성첨단소재',
#    'TDD_CLSPRC': '466,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-3,500',
#    'FLUC_RT': '-0.74',
#    'MKTCAP': '2,089,895,742,000'},
#   {'ISU_SRT_CD': '069620',
#    'ISU_ABBRV': '대웅제약',
#    'TDD_CLSPRC': '182,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-0.54',
#    'MKTCAP': '2,114,549,937,500'},
#   {'ISU_SRT_CD': '004000',
#    'ISU_ABBRV': '롯데정밀화학',
#    'TDD_CLSPRC': '81,300',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-800',
#    'FLUC_RT': '-0.97',
#    'MKTCAP': '2,097,540,000,000'},
#   {'ISU_SRT_CD': '111770',
#    'ISU_ABBRV': '영원무역',
#    'TDD_CLSPRC': '47,450',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-550',
#    'FLUC_RT': '-1.15',
#    'MKTCAP': '2,102,579,156,600'},
#   {'ISU_SRT_CD': '064350',
#    'ISU_ABBRV': '현대로템',
#    'TDD_CLSPRC': '19,050',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.26',
#    'MKTCAP': '2,079,160,681,650'},
#   {'ISU_SRT_CD': '081660',
#    'ISU_ABBRV': '휠라홀딩스',
#    'TDD_CLSPRC': '32,050',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-0.47',
#    'MKTCAP': '1,947,108,715,100'},
#   {'ISU_SRT_CD': '298020',
#    'ISU_ABBRV': '효성티앤씨',
#    'TDD_CLSPRC': '405,000',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '1,752,711,210,000'},
#   {'ISU_SRT_CD': '069960',
#    'ISU_ABBRV': '현대백화점',
#    'TDD_CLSPRC': '75,300',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-700',
#    'FLUC_RT': '-0.92',
#    'MKTCAP': '1,762,203,807,300'},
#   {'ISU_SRT_CD': '079550',
#    'ISU_ABBRV': 'LIG넥스원',
#    'TDD_CLSPRC': '86,800',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,300',
#    'FLUC_RT': '1.52',
#    'MKTCAP': '1,909,600,000,000'},
#   {'ISU_SRT_CD': '093370',
#    'ISU_ABBRV': '후성',
#    'TDD_CLSPRC': '19,650',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '600',
#    'FLUC_RT': '3.15',
#    'MKTCAP': '1,819,723,993,350'},
#   {'ISU_SRT_CD': '051600',
#    'ISU_ABBRV': '한전KPS',
#    'TDD_CLSPRC': '38,700',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '600',
#    'FLUC_RT': '1.57',
#    'MKTCAP': '1,741,500,000,000'},
#   {'ISU_SRT_CD': '004370',
#    'ISU_ABBRV': '농심',
#    'TDD_CLSPRC': '300,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-6,000',
#    'FLUC_RT': '-1.96',
#    'MKTCAP': '1,824,792,600,000'},
#   {'ISU_SRT_CD': '005300',
#    'ISU_ABBRV': '롯데칠성',
#    'TDD_CLSPRC': '199,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-500',
#    'FLUC_RT': '-0.25',
#    'MKTCAP': '1,851,137,358,000'},
#   {'ISU_SRT_CD': '006260',
#    'ISU_ABBRV': 'LS',
#    'TDD_CLSPRC': '56,600',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-900',
#    'FLUC_RT': '-1.57',
#    'MKTCAP': '1,822,520,000,000'},
#   {'ISU_SRT_CD': '011210',
#    'ISU_ABBRV': '현대위아',
#    'TDD_CLSPRC': '64,800',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,300',
#    'FLUC_RT': '-1.97',
#    'MKTCAP': '1,762,241,378,400'},
#   {'ISU_SRT_CD': '001230',
#    'ISU_ABBRV': '동국제강',
#    'TDD_CLSPRC': '19,050',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-300',
#    'FLUC_RT': '-1.55',
#    'MKTCAP': '1,817,993,639,850'},
#   {'ISU_SRT_CD': '003090',
#    'ISU_ABBRV': '대웅',
#    'TDD_CLSPRC': '29,950',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '200',
#    'FLUC_RT': '0.67',
#    'MKTCAP': '1,741,352,301,000'},
#   {'ISU_SRT_CD': '004800',
#    'ISU_ABBRV': '효성',
#    'TDD_CLSPRC': '83,400',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '400',
#    'FLUC_RT': '0.48',
#    'MKTCAP': '1,757,323,485,000'},
#   {'ISU_SRT_CD': '353200',
#    'ISU_ABBRV': '대덕전자',
#    'TDD_CLSPRC': '31,800',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,100',
#    'FLUC_RT': '3.58',
#    'MKTCAP': '1,571,458,215,000'},
#   {'ISU_SRT_CD': '089860',
#    'ISU_ABBRV': '롯데렌탈',
#    'TDD_CLSPRC': '43,650',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '1,599,076,849,950'},
#   {'ISU_SRT_CD': '120110',
#    'ISU_ABBRV': '코오롱인더',
#    'TDD_CLSPRC': '62,600',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '400',
#    'FLUC_RT': '0.64',
#    'MKTCAP': '1,722,695,096,600'},
#   {'ISU_SRT_CD': '175330',
#    'ISU_ABBRV': 'JB금융지주',
#    'TDD_CLSPRC': '8,790',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-70',
#    'FLUC_RT': '-0.79',
#    'MKTCAP': '1,731,479,638,260'},
#   {'ISU_SRT_CD': '019170',
#    'ISU_ABBRV': '신풍제약',
#    'TDD_CLSPRC': '29,100',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-750',
#    'FLUC_RT': '-2.51',
#    'MKTCAP': '1,541,863,209,000'},
#   {'ISU_SRT_CD': '001120',
#    'ISU_ABBRV': 'LX인터내셔널',
#    'TDD_CLSPRC': '39,600',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,150',
#    'FLUC_RT': '2.99',
#    'MKTCAP': '1,534,896,000,000'},
#   {'ISU_SRT_CD': '007310',
#    'ISU_ABBRV': '오뚜기',
#    'TDD_CLSPRC': '456,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-9,000',
#    'FLUC_RT': '-1.94',
#    'MKTCAP': '1,674,423,336,000'},
#   {'ISU_SRT_CD': '009240',
#    'ISU_ABBRV': '한샘',
#    'TDD_CLSPRC': '70,400',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,400',
#    'FLUC_RT': '-1.95',
#    'MKTCAP': '1,656,788,531,200'},
#   {'ISU_SRT_CD': '010780',
#    'ISU_ABBRV': '아이에스동서',
#    'TDD_CLSPRC': '53,600',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '600',
#    'FLUC_RT': '1.13',
#    'MKTCAP': '1,655,843,681,600'},
#   {'ISU_SRT_CD': '014820',
#    'ISU_ABBRV': '동원시스템즈',
#    'TDD_CLSPRC': '57,400',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,600',
#    'FLUC_RT': '-2.71',
#    'MKTCAP': '1,675,414,791,400'},
#   {'ISU_SRT_CD': '005070',
#    'ISU_ABBRV': '코스모신소재',
#    'TDD_CLSPRC': '55,100',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '500',
#    'FLUC_RT': '0.92',
#    'MKTCAP': '1,657,787,583,900'},
#   {'ISU_SRT_CD': '271940',
#    'ISU_ABBRV': '일진하이솔루스',
#    'TDD_CLSPRC': '40,800',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '650',
#    'FLUC_RT': '1.62',
#    'MKTCAP': '1,481,578,152,000'},
#   {'ISU_SRT_CD': '300720',
#    'ISU_ABBRV': '한일시멘트',
#    'TDD_CLSPRC': '20,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-200',
#    'FLUC_RT': '-0.97',
#    'MKTCAP': '1,419,861,570,000'},
#   {'ISU_SRT_CD': '139130',
#    'ISU_ABBRV': 'DGB금융지주',
#    'TDD_CLSPRC': '8,850',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '1,496,940,622,050'},
#   {'ISU_SRT_CD': '178920',
#    'ISU_ABBRV': 'PI첨단소재',
#    'TDD_CLSPRC': '47,950',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-0.31',
#    'MKTCAP': '1,408,115,139,900'},
#   {'ISU_SRT_CD': '181710',
#    'ISU_ABBRV': 'NHN',
#    'TDD_CLSPRC': '35,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-0.42',
#    'MKTCAP': '1,331,885,982,500'},
#   {'ISU_SRT_CD': '249420',
#    'ISU_ABBRV': '일동제약',
#    'TDD_CLSPRC': '50,900',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,600',
#    'FLUC_RT': '-3.05',
#    'MKTCAP': '1,364,287,206,500'},
#   {'ISU_SRT_CD': '017800',
#    'ISU_ABBRV': '현대엘리베이',
#    'TDD_CLSPRC': '35,800',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '300',
#    'FLUC_RT': '0.85',
#    'MKTCAP': '1,461,183,837,800'},
#   {'ISU_SRT_CD': '020560',
#    'ISU_ABBRV': '아시아나항공',
#    'TDD_CLSPRC': '19,950',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-200',
#    'FLUC_RT': '-0.99',
#    'MKTCAP': '1,484,514,691,800'},
#   {'ISU_SRT_CD': '042670',
#    'ISU_ABBRV': '현대두산인프라코어',
#    'TDD_CLSPRC': '6,760',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '170',
#    'FLUC_RT': '2.58',
#    'MKTCAP': '1,334,801,627,120'},
#   {'ISU_SRT_CD': '042700',
#    'ISU_ABBRV': '한미반도체',
#    'TDD_CLSPRC': '15,050',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '50',
#    'FLUC_RT': '0.33',
#    'MKTCAP': '1,488,742,297,700'},
#   {'ISU_SRT_CD': '010120',
#    'ISU_ABBRV': 'LS ELECTRIC',
#    'TDD_CLSPRC': '50,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '50',
#    'FLUC_RT': '0.10',
#    'MKTCAP': '1,500,000,000,000'},
#   {'ISU_SRT_CD': '330590',
#    'ISU_ABBRV': '롯데리츠',
#    'TDD_CLSPRC': '5,840',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-120',
#    'FLUC_RT': '-2.01',
#    'MKTCAP': '1,418,938,282,560'},
#   {'ISU_SRT_CD': '365550',
#    'ISU_ABBRV': 'ESR켄달스퀘어리츠',
#    'TDD_CLSPRC': '6,980',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-220',
#    'FLUC_RT': '-3.06',
#    'MKTCAP': '1,487,361,220,000'},
#   {'ISU_SRT_CD': '000150',
#    'ISU_ABBRV': '두산',
#    'TDD_CLSPRC': '89,600',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,900',
#    'FLUC_RT': '2.17',
#    'MKTCAP': '1,480,535,616,000'},
#   {'ISU_SRT_CD': '000210',
#    'ISU_ABBRV': 'DL',
#    'TDD_CLSPRC': '65,400',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '3,200',
#    'FLUC_RT': '5.14',
#    'MKTCAP': '1,370,514,813,600'},
#   {'ISU_SRT_CD': '000240',
#    'ISU_ABBRV': '한국앤컴퍼니',
#    'TDD_CLSPRC': '14,400',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-100',
#    'FLUC_RT': '-0.69',
#    'MKTCAP': '1,367,067,456,000'},
#   {'ISU_SRT_CD': '363280',
#    'ISU_ABBRV': '티와이홀딩스',
#    'TDD_CLSPRC': '25,100',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.20',
#    'MKTCAP': '1,278,324,626,800'},
#   {'ISU_SRT_CD': '003690',
#    'ISU_ABBRV': '코리안리',
#    'TDD_CLSPRC': '9,770',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-100',
#    'FLUC_RT': '-1.01',
#    'MKTCAP': '1,176,006,263,320'},
#   {'ISU_SRT_CD': '073240',
#    'ISU_ABBRV': '금호타이어',
#    'TDD_CLSPRC': '4,215',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-25',
#    'FLUC_RT': '-0.59',
#    'MKTCAP': '1,210,802,109,705'},
#   {'ISU_SRT_CD': '185750',
#    'ISU_ABBRV': '종근당',
#    'TDD_CLSPRC': '98,200',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '300',
#    'FLUC_RT': '0.31',
#    'MKTCAP': '1,177,225,331,600'},
#   {'ISU_SRT_CD': '195870',
#    'ISU_ABBRV': '해성디에스',
#    'TDD_CLSPRC': '71,600',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,200',
#    'FLUC_RT': '1.70',
#    'MKTCAP': '1,217,200,000,000'},
#   {'ISU_SRT_CD': '248070',
#    'ISU_ABBRV': '솔루엠',
#    'TDD_CLSPRC': '25,650',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,400',
#    'FLUC_RT': '5.77',
#    'MKTCAP': '1,282,642,383,150'},
#   {'ISU_SRT_CD': '018670',
#    'ISU_ABBRV': 'SK가스',
#    'TDD_CLSPRC': '136,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '9,000',
#    'FLUC_RT': '7.09',
#    'MKTCAP': '1,255,313,184,000'},
#   {'ISU_SRT_CD': '031430',
#    'ISU_ABBRV': '신세계인터내셔날',
#    'TDD_CLSPRC': '32,150',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '250',
#    'FLUC_RT': '0.78',
#    'MKTCAP': '1,147,755,000,000'},
#   {'ISU_SRT_CD': '032350',
#    'ISU_ABBRV': '롯데관광개발',
#    'TDD_CLSPRC': '16,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-300',
#    'FLUC_RT': '-1.84',
#    'MKTCAP': '1,151,663,296,000'},
#   {'ISU_SRT_CD': '039130',
#    'ISU_ABBRV': '하나투어',
#    'TDD_CLSPRC': '82,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,100',
#    'FLUC_RT': '-1.32',
#    'MKTCAP': '1,143,013,170,000'},
#   {'ISU_SRT_CD': '005850',
#    'ISU_ABBRV': '에스엘',
#    'TDD_CLSPRC': '26,750',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-350',
#    'FLUC_RT': '-1.29',
#    'MKTCAP': '1,289,437,659,750'},
#   {'ISU_SRT_CD': '009900',
#    'ISU_ABBRV': '명신산업',
#    'TDD_CLSPRC': '22,750',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-100',
#    'FLUC_RT': '-0.44',
#    'MKTCAP': '1,193,695,525,750'},
#   {'ISU_SRT_CD': '012510',
#    'ISU_ABBRV': '더존비즈온',
#    'TDD_CLSPRC': '41,350',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '150',
#    'FLUC_RT': '0.36',
#    'MKTCAP': '1,256,328,118,400'},
#   {'ISU_SRT_CD': '000670',
#    'ISU_ABBRV': '영풍',
#    'TDD_CLSPRC': '684,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '4,000',
#    'FLUC_RT': '0.59',
#    'MKTCAP': '1,259,955,360,000'},
#   {'ISU_SRT_CD': '001740',
#    'ISU_ABBRV': 'SK네트웍스',
#    'TDD_CLSPRC': '4,820',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-20',
#    'FLUC_RT': '-0.41',
#    'MKTCAP': '1,196,264,458,540'},
#   {'ISU_SRT_CD': '003240',
#    'ISU_ABBRV': '태광산업',
#    'TDD_CLSPRC': '1,015,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-0.10',
#    'MKTCAP': '1,130,101,000,000'},
#   {'ISU_SRT_CD': '381970',
#    'ISU_ABBRV': '케이카',
#    'TDD_CLSPRC': '27,300',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '300',
#    'FLUC_RT': '1.11',
#    'MKTCAP': '1,312,762,350,900'},
#   {'ISU_SRT_CD': '268280',
#    'ISU_ABBRV': '미원에스씨',
#    'TDD_CLSPRC': '207,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-2,500',
#    'FLUC_RT': '-1.19',
#    'MKTCAP': '1,055,700,000,000'},
#   {'ISU_SRT_CD': '003530',
#    'ISU_ABBRV': '한화투자증권',
#    'TDD_CLSPRC': '4,770',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '10',
#    'FLUC_RT': '0.21',
#    'MKTCAP': '1,023,392,886,750'},
#   {'ISU_SRT_CD': '294870',
#    'ISU_ABBRV': 'HDC현대산업개발',
#    'TDD_CLSPRC': '14,950',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-0.99',
#    'MKTCAP': '985,314,583,500'},
#   {'ISU_SRT_CD': '344820',
#    'ISU_ABBRV': 'KCC글라스',
#    'TDD_CLSPRC': '62,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-200',
#    'FLUC_RT': '-0.32',
#    'MKTCAP': '990,171,744,000'},
#   {'ISU_SRT_CD': '079160',
#    'ISU_ABBRV': 'CJ CGV',
#    'TDD_CLSPRC': '27,300',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-0.55',
#    'MKTCAP': '1,114,747,042,500'},
#   {'ISU_SRT_CD': '082640',
#    'ISU_ABBRV': '동양생명',
#    'TDD_CLSPRC': '6,650',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-60',
#    'FLUC_RT': '-0.89',
#    'MKTCAP': '1,073,034,590,250'},
#   {'ISU_SRT_CD': '089590',
#    'ISU_ABBRV': '제주항공',
#    'TDD_CLSPRC': '21,350',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-450',
#    'FLUC_RT': '-2.06',
#    'MKTCAP': '1,062,368,911,800'},
#   {'ISU_SRT_CD': '105630',
#    'ISU_ABBRV': '한세실업',
#    'TDD_CLSPRC': '26,550',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-0.56',
#    'MKTCAP': '1,062,000,000,000'},
#   {'ISU_SRT_CD': '114090',
#    'ISU_ABBRV': 'GKL',
#    'TDD_CLSPRC': '15,050',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-300',
#    'FLUC_RT': '-1.95',
#    'MKTCAP': '930,927,833,500'},
#   {'ISU_SRT_CD': '161890',
#    'ISU_ABBRV': '한국콜마',
#    'TDD_CLSPRC': '45,850',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,200',
#    'FLUC_RT': '-2.55',
#    'MKTCAP': '1,049,102,103,000'},
#   {'ISU_SRT_CD': '192820',
#    'ISU_ABBRV': '코스맥스',
#    'TDD_CLSPRC': '82,400',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-2,700',
#    'FLUC_RT': '-3.17',
#    'MKTCAP': '935,199,541,600'},
#   {'ISU_SRT_CD': '214320',
#    'ISU_ABBRV': '이노션',
#    'TDD_CLSPRC': '49,200',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '100',
#    'FLUC_RT': '0.20',
#    'MKTCAP': '984,000,000,000'},
#   {'ISU_SRT_CD': '241590',
#    'ISU_ABBRV': '화승엔터프라이즈',
#    'TDD_CLSPRC': '16,550',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-550',
#    'FLUC_RT': '-3.22',
#    'MKTCAP': '1,002,607,457,050'},
#   {'ISU_SRT_CD': '014830',
#    'ISU_ABBRV': '유니드',
#    'TDD_CLSPRC': '122,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-5,500',
#    'FLUC_RT': '-4.31',
#    'MKTCAP': '1,084,560,846,000'},
#   {'ISU_SRT_CD': '016710',
#    'ISU_ABBRV': '대성홀딩스',
#    'TDD_CLSPRC': '58,700',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-200',
#    'FLUC_RT': '-0.34',
#    'MKTCAP': '944,451,243,300'},
#   {'ISU_SRT_CD': '017390',
#    'ISU_ABBRV': '서울가스',
#    'TDD_CLSPRC': '183,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,500',
#    'FLUC_RT': '-0.81',
#    'MKTCAP': '917,500,000,000'},
#   {'ISU_SRT_CD': '023590',
#    'ISU_ABBRV': '다우기술',
#    'TDD_CLSPRC': '20,900',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '300',
#    'FLUC_RT': '1.46',
#    'MKTCAP': '937,712,295,300'},
#   {'ISU_SRT_CD': '034120',
#    'ISU_ABBRV': 'SBS',
#    'TDD_CLSPRC': '52,400',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,900',
#    'FLUC_RT': '3.76',
#    'MKTCAP': '956,435,296,800'},
#   {'ISU_SRT_CD': '036420',
#    'ISU_ABBRV': '콘텐트리중앙',
#    'TDD_CLSPRC': '48,800',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '2,400',
#    'FLUC_RT': '5.17',
#    'MKTCAP': '930,742,782,400'},
#   {'ISU_SRT_CD': '004490',
#    'ISU_ABBRV': '세방전지',
#    'TDD_CLSPRC': '73,800',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,100',
#    'FLUC_RT': '1.51',
#    'MKTCAP': '1,033,200,000,000'},
#   {'ISU_SRT_CD': '005250',
#    'ISU_ABBRV': '녹십자홀딩스',
#    'TDD_CLSPRC': '21,900',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-0.68',
#    'MKTCAP': '1,029,917,799,000'},
#   {'ISU_SRT_CD': '006650',
#    'ISU_ABBRV': '대한유화',
#    'TDD_CLSPRC': '153,500',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,500',
#    'FLUC_RT': '0.99',
#    'MKTCAP': '997,750,000,000'},
#   {'ISU_SRT_CD': '007700',
#    'ISU_ABBRV': 'F&F홀딩스',
#    'TDD_CLSPRC': '25,900',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-250',
#    'FLUC_RT': '-0.96',
#    'MKTCAP': '1,013,062,105,300'},
#   {'ISU_SRT_CD': '009420',
#    'ISU_ABBRV': '한올바이오파마',
#    'TDD_CLSPRC': '18,150',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-300',
#    'FLUC_RT': '-1.63',
#    'MKTCAP': '948,167,579,700'},
#   {'ISU_SRT_CD': '013890',
#    'ISU_ABBRV': '지누스',
#    'TDD_CLSPRC': '63,800',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '800',
#    'FLUC_RT': '1.27',
#    'MKTCAP': '1,008,068,710,000'},
#   {'ISU_SRT_CD': '348950',
#    'ISU_ABBRV': '제이알글로벌리츠',
#    'TDD_CLSPRC': '5,780',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-110',
#    'FLUC_RT': '-1.87',
#    'MKTCAP': '957,168,000,000'},
#   {'ISU_SRT_CD': '395400',
#    'ISU_ABBRV': 'SK리츠',
#    'TDD_CLSPRC': '7,050',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-80',
#    'FLUC_RT': '-1.12',
#    'MKTCAP': '1,092,894,750,600'},
#   {'ISU_SRT_CD': '001800',
#    'ISU_ABBRV': '오리온홀딩스',
#    'TDD_CLSPRC': '14,700',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.34',
#    'MKTCAP': '920,887,703,400'},
#   {'ISU_SRT_CD': '272450',
#    'ISU_ABBRV': '진에어',
#    'TDD_CLSPRC': '18,050',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.28',
#    'MKTCAP': '942,210,000,000'},
#   {'ISU_SRT_CD': '267260',
#    'ISU_ABBRV': '현대일렉트릭',
#    'TDD_CLSPRC': '24,050',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,150',
#    'FLUC_RT': '5.02',
#    'MKTCAP': '866,933,596,750'},
#   {'ISU_SRT_CD': '003850',
#    'ISU_ABBRV': '보령',
#    'TDD_CLSPRC': '12,700',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-200',
#    'FLUC_RT': '-1.55',
#    'MKTCAP': '872,363,000,000'},
#   {'ISU_SRT_CD': '280360',
#    'ISU_ABBRV': '롯데제과',
#    'TDD_CLSPRC': '124,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-0.80',
#    'MKTCAP': '795,672,908,000'},
#   {'ISU_SRT_CD': '284740',
#    'ISU_ABBRV': '쿠쿠홈시스',
#    'TDD_CLSPRC': '34,700',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-450',
#    'FLUC_RT': '-1.28',
#    'MKTCAP': '778,575,351,000'},
#   {'ISU_SRT_CD': '298000',
#    'ISU_ABBRV': '효성화학',
#    'TDD_CLSPRC': '224,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,000',
#    'FLUC_RT': '0.45',
#    'MKTCAP': '714,588,224,000'},
#   {'ISU_SRT_CD': '383800',
#    'ISU_ABBRV': 'LX홀딩스',
#    'TDD_CLSPRC': '9,960',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-40',
#    'FLUC_RT': '-0.40',
#    'MKTCAP': '759,755,672,400'},
#   {'ISU_SRT_CD': '069260',
#    'ISU_ABBRV': 'TKG휴켐스',
#    'TDD_CLSPRC': '22,100',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-0.67',
#    'MKTCAP': '903,416,794,800'},
#   {'ISU_SRT_CD': '097520',
#    'ISU_ABBRV': '엠씨넥스',
#    'TDD_CLSPRC': '43,100',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-200',
#    'FLUC_RT': '-0.46',
#    'MKTCAP': '774,784,219,200'},
#   {'ISU_SRT_CD': '103140',
#    'ISU_ABBRV': '풍산',
#    'TDD_CLSPRC': '32,100',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-350',
#    'FLUC_RT': '-1.08',
#    'MKTCAP': '899,579,323,800'},
#   {'ISU_SRT_CD': '145720',
#    'ISU_ABBRV': '덴티움',
#    'TDD_CLSPRC': '71,200',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-300',
#    'FLUC_RT': '-0.42',
#    'MKTCAP': '788,100,696,000'},
#   {'ISU_SRT_CD': '192080',
#    'ISU_ABBRV': '더블유게임즈',
#    'TDD_CLSPRC': '49,100',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-500',
#    'FLUC_RT': '-1.01',
#    'MKTCAP': '902,188,048,200'},
#   {'ISU_SRT_CD': '020000',
#    'ISU_ABBRV': '한섬',
#    'TDD_CLSPRC': '35,400',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-450',
#    'FLUC_RT': '-1.26',
#    'MKTCAP': '871,902,000,000'},
#   {'ISU_SRT_CD': '025540',
#    'ISU_ABBRV': '한국단자',
#    'TDD_CLSPRC': '69,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-100',
#    'FLUC_RT': '-0.14',
#    'MKTCAP': '718,635,000,000'},
#   {'ISU_SRT_CD': '025860',
#    'ISU_ABBRV': '남해화학',
#    'TDD_CLSPRC': '14,650',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '250',
#    'FLUC_RT': '1.74',
#    'MKTCAP': '727,795,049,950'},
#   {'ISU_SRT_CD': '057050',
#    'ISU_ABBRV': '현대홈쇼핑',
#    'TDD_CLSPRC': '60,000',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '720,000,000,000'},
#   {'ISU_SRT_CD': '005090',
#    'ISU_ABBRV': 'SGC에너지',
#    'TDD_CLSPRC': '49,700',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-400',
#    'FLUC_RT': '-0.80',
#    'MKTCAP': '729,447,098,800'},
#   {'ISU_SRT_CD': '005440',
#    'ISU_ABBRV': '현대그린푸드',
#    'TDD_CLSPRC': '9,100',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-70',
#    'FLUC_RT': '-0.76',
#    'MKTCAP': '889,110,786,200'},
#   {'ISU_SRT_CD': '005610',
#    'ISU_ABBRV': 'SPC삼립',
#    'TDD_CLSPRC': '89,800',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,400',
#    'FLUC_RT': '-1.54',
#    'MKTCAP': '774,885,008,200'},
#   {'ISU_SRT_CD': '005880',
#    'ISU_ABBRV': '대한해운',
#    'TDD_CLSPRC': '2,740',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '10',
#    'FLUC_RT': '0.37',
#    'MKTCAP': '874,546,240,400'},
#   {'ISU_SRT_CD': '006040',
#    'ISU_ABBRV': '동원산업',
#    'TDD_CLSPRC': '239,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-6,500',
#    'FLUC_RT': '-2.65',
#    'MKTCAP': '878,956,199,000'},
#   {'ISU_SRT_CD': '006120',
#    'ISU_ABBRV': 'SK디스커버리',
#    'TDD_CLSPRC': '42,200',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '803,397,481,000'},
#   {'ISU_SRT_CD': '007340',
#    'ISU_ABBRV': '디티알오토모티브',
#    'TDD_CLSPRC': '76,400',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-300',
#    'FLUC_RT': '-0.39',
#    'MKTCAP': '763,541,982,000'},
#   {'ISU_SRT_CD': '009450',
#    'ISU_ABBRV': '경동나비엔',
#    'TDD_CLSPRC': '52,700',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '300',
#    'FLUC_RT': '0.57',
#    'MKTCAP': '767,764,798,400'},
#   {'ISU_SRT_CD': '010050',
#    'ISU_ABBRV': '우리종금',
#    'TDD_CLSPRC': '875',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '3',
#    'FLUC_RT': '0.34',
#    'MKTCAP': '764,927,980,250'},
#   {'ISU_SRT_CD': '011000',
#    'ISU_ABBRV': '진원생명과학',
#    'TDD_CLSPRC': '11,150',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '50',
#    'FLUC_RT': '0.45',
#    'MKTCAP': '866,115,297,300'},
#   {'ISU_SRT_CD': '000070',
#    'ISU_ABBRV': '삼양홀딩스',
#    'TDD_CLSPRC': '85,000',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,200',
#    'FLUC_RT': '-1.39',
#    'MKTCAP': '727,963,035,000'},
#   {'ISU_SRT_CD': '000640',
#    'ISU_ABBRV': '동아쏘시오홀딩스',
#    'TDD_CLSPRC': '115,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,500',
#    'FLUC_RT': '1.32',
#    'MKTCAP': '730,124,995,000'},
#   {'ISU_SRT_CD': '001680',
#    'ISU_ABBRV': '대상',
#    'TDD_CLSPRC': '24,700',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-500',
#    'FLUC_RT': '-1.98',
#    'MKTCAP': '855,806,217,500'},
#   {'ISU_SRT_CD': '002840',
#    'ISU_ABBRV': '미원상사',
#    'TDD_CLSPRC': '168,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,000',
#    'FLUC_RT': '-0.59',
#    'MKTCAP': '837,445,000,000'},
#   {'ISU_SRT_CD': '003000',
#    'ISU_ABBRV': '부광약품',
#    'TDD_CLSPRC': '11,700',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-200',
#    'FLUC_RT': '-1.68',
#    'MKTCAP': '831,437,673,300'},
#   {'ISU_SRT_CD': '003230',
#    'ISU_ABBRV': '삼양식품',
#    'TDD_CLSPRC': '96,200',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-2,000',
#    'FLUC_RT': '-2.04',
#    'MKTCAP': '724,676,043,000'},
#   {'ISU_SRT_CD': '003520',
#    'ISU_ABBRV': '영진약품',
#    'TDD_CLSPRC': '4,850',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-40',
#    'FLUC_RT': '-0.82',
#    'MKTCAP': '887,029,745,350'},
#   {'ISU_SRT_CD': '003540',
#    'ISU_ABBRV': '대신증권',
#    'TDD_CLSPRC': '17,250',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.29',
#    'MKTCAP': '875,841,150,000'},
#   {'ISU_SRT_CD': '267270',
#    'ISU_ABBRV': '현대건설기계',
#    'TDD_CLSPRC': '40,300',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '1,600',
#    'FLUC_RT': '4.13',
#    'MKTCAP': '793,941,957,900'},
#   {'ISU_SRT_CD': '286940',
#    'ISU_ABBRV': '롯데정보통신',
#    'TDD_CLSPRC': '34,100',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,400',
#    'FLUC_RT': '-3.94',
#    'MKTCAP': '525,014,887,100'},
# ...
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-70',
#    'FLUC_RT': '-4.81',
#    'MKTCAP': '23,490,140,150'},
#   {'ISU_SRT_CD': '033250',
#    'ISU_ABBRV': '체시스',
#    'TDD_CLSPRC': '1,345',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '20',
#    'FLUC_RT': '1.51',
#    'MKTCAP': '43,040,000,000'},
#   {'ISU_SRT_CD': '041650',
#    'ISU_ABBRV': '상신브레이크',
#    'TDD_CLSPRC': '4,050',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '30',
#    'FLUC_RT': '0.75',
#    'MKTCAP': '86,959,372,500'},
#   {'ISU_SRT_CD': '044380',
#    'ISU_ABBRV': '주연테크',
#    'TDD_CLSPRC': '1,080',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '10',
#    'FLUC_RT': '0.93',
#    'MKTCAP': '63,935,183,520'},
#   {'ISU_SRT_CD': '049800',
#    'ISU_ABBRV': '우진플라임',
#    'TDD_CLSPRC': '4,755',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '20',
#    'FLUC_RT': '0.42',
#    'MKTCAP': '95,100,000,000'},
#   {'ISU_SRT_CD': '051630',
#    'ISU_ABBRV': '진양화학',
#    'TDD_CLSPRC': '5,690',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '50',
#    'FLUC_RT': '0.89',
#    'MKTCAP': '68,280,000,000'},
#   {'ISU_SRT_CD': '058730',
#    'ISU_ABBRV': '다스코',
#    'TDD_CLSPRC': '5,270',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '365',
#    'FLUC_RT': '7.44',
#    'MKTCAP': '88,939,476,470'},
#   {'ISU_SRT_CD': '058860',
#    'ISU_ABBRV': 'KTis',
#    'TDD_CLSPRC': '2,655',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '5',
#    'FLUC_RT': '0.19',
#    'MKTCAP': '92,399,310,000'},
#   {'ISU_SRT_CD': '069640',
#    'ISU_ABBRV': '한세엠케이',
#    'TDD_CLSPRC': '4,130',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-5',
#    'FLUC_RT': '-0.12',
#    'MKTCAP': '53,315,499,860'},
#   {'ISU_SRT_CD': '069730',
#    'ISU_ABBRV': 'DSR제강',
#    'TDD_CLSPRC': '6,740',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '240',
#    'FLUC_RT': '3.69',
#    'MKTCAP': '97,056,000,000'},
#   {'ISU_SRT_CD': '071950',
#    'ISU_ABBRV': '코아스',
#    'TDD_CLSPRC': '1,110',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '34,307,003,100'},
#   {'ISU_SRT_CD': '072130',
#    'ISU_ABBRV': '유엔젤',
#    'TDD_CLSPRC': '4,580',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '60,435,179,320'},
#   {'ISU_SRT_CD': '084670',
#    'ISU_ABBRV': '동양고속',
#    'TDD_CLSPRC': '18,950',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-250',
#    'FLUC_RT': '-1.30',
#    'MKTCAP': '54,871,032,550'},
#   {'ISU_SRT_CD': '084870',
#    'ISU_ABBRV': 'TBH글로벌',
#    'TDD_CLSPRC': '2,275',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '45',
#    'FLUC_RT': '2.02',
#    'MKTCAP': '47,449,263,225'},
#   {'ISU_SRT_CD': '085310',
#    'ISU_ABBRV': '엔케이',
#    'TDD_CLSPRC': '1,170',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-20',
#    'FLUC_RT': '-1.68',
#    'MKTCAP': '93,580,521,840'},
#   {'ISU_SRT_CD': '088790',
#    'ISU_ABBRV': '진도',
#    'TDD_CLSPRC': '3,985',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '25',
#    'FLUC_RT': '0.63',
#    'MKTCAP': '49,604,259,840'},
#   {'ISU_SRT_CD': '090080',
#    'ISU_ABBRV': '평화산업',
#    'TDD_CLSPRC': '1,780',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-5',
#    'FLUC_RT': '-0.28',
#    'MKTCAP': '97,726,021,020'},
#   {'ISU_SRT_CD': '090370',
#    'ISU_ABBRV': '메타랩스',
#    'TDD_CLSPRC': '849',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '2',
#    'FLUC_RT': '0.24',
#    'MKTCAP': '63,270,407,352'},
#   {'ISU_SRT_CD': '092780',
#    'ISU_ABBRV': '동양피스톤',
#    'TDD_CLSPRC': '6,720',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '280',
#    'FLUC_RT': '4.35',
#    'MKTCAP': '88,492,051,200'},
#   {'ISU_SRT_CD': '093240',
#    'ISU_ABBRV': '형지엘리트',
#    'TDD_CLSPRC': '2,050',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '50',
#    'FLUC_RT': '2.50',
#    'MKTCAP': '63,867,335,900'},
#   {'ISU_SRT_CD': '100220',
#    'ISU_ABBRV': '비상교육',
#    'TDD_CLSPRC': '7,700',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '50',
#    'FLUC_RT': '0.65',
#    'MKTCAP': '100,074,905,700'},
#   {'ISU_SRT_CD': '109070',
#    'ISU_ABBRV': '컨버즈',
#    'TDD_CLSPRC': '4,100',
#    'FLUC_TP_CD': '0',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '71,952,027,500'},
#   {'ISU_SRT_CD': '119650',
#    'ISU_ABBRV': 'KC코트렐',
#    'TDD_CLSPRC': '5,560',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '90',
#    'FLUC_RT': '1.65',
#    'MKTCAP': '97,856,000,000'},
#   {'ISU_SRT_CD': '123700',
#    'ISU_ABBRV': 'SJM',
#    'TDD_CLSPRC': '4,465',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '85',
#    'FLUC_RT': '1.94',
#    'MKTCAP': '69,675,869,570'},
#   {'ISU_SRT_CD': '145210',
#    'ISU_ABBRV': '다이나믹디자인',
#    'TDD_CLSPRC': '238',
#    'FLUC_TP_CD': '0',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '37,672,840,548'},
#   {'ISU_SRT_CD': '378850',
#    'ISU_ABBRV': '화승알앤에이',
#    'TDD_CLSPRC': '4,535',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '86,136,080,305'},
#   {'ISU_SRT_CD': '140910',
#    'ISU_ABBRV': '에이리츠',
#    'TDD_CLSPRC': '7,780',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '60',
#    'FLUC_RT': '0.78',
#    'MKTCAP': '34,722,388,960'},
#   {'ISU_SRT_CD': '145270',
#    'ISU_ABBRV': '케이탑리츠',
#    'TDD_CLSPRC': '1,480',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-15',
#    'FLUC_RT': '-1.00',
#    'MKTCAP': '71,129,945,520'},
#   {'ISU_SRT_CD': '204210',
#    'ISU_ABBRV': '모두투어리츠',
#    'TDD_CLSPRC': '5,200',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-60',
#    'FLUC_RT': '-1.14',
#    'MKTCAP': '40,699,438,000'},
#   {'ISU_SRT_CD': '338100',
#    'ISU_ABBRV': 'NH프라임리츠',
#    'TDD_CLSPRC': '5,030',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-70',
#    'FLUC_RT': '-1.37',
#    'MKTCAP': '93,859,800,000'},
#   {'ISU_SRT_CD': '155900',
#    'ISU_ABBRV': '바다로19호',
#    'TDD_CLSPRC': '3,270',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-5',
#    'FLUC_RT': '-0.15',
#    'MKTCAP': '49,704,013,080'},
#   {'ISU_SRT_CD': '000040',
#    'ISU_ABBRV': 'KR모터스',
#    'TDD_CLSPRC': '859',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '4',
#    'FLUC_RT': '0.47',
#    'MKTCAP': '82,581,999,112'},
#   {'ISU_SRT_CD': '000590',
#    'ISU_ABBRV': 'CS홀딩스',
#    'TDD_CLSPRC': '68,100',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '500',
#    'FLUC_RT': '0.74',
#    'MKTCAP': '78,620,224,200'},
#   {'ISU_SRT_CD': '000650',
#    'ISU_ABBRV': '천일고속',
#    'TDD_CLSPRC': '67,600',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '100',
#    'FLUC_RT': '0.15',
#    'MKTCAP': '96,615,272,000'},
#   {'ISU_SRT_CD': '000760',
#    'ISU_ABBRV': '이화산업',
#    'TDD_CLSPRC': '18,400',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '100',
#    'FLUC_RT': '0.55',
#    'MKTCAP': '51,520,000,000'},
#   {'ISU_SRT_CD': '000850',
#    'ISU_ABBRV': '화천기공',
#    'TDD_CLSPRC': '36,200',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '450',
#    'FLUC_RT': '1.26',
#    'MKTCAP': '79,640,000,000'},
#   {'ISU_SRT_CD': '000950',
#    'ISU_ABBRV': '전방',
#    'TDD_CLSPRC': '53,500',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1,200',
#    'FLUC_RT': '-2.19',
#    'MKTCAP': '89,880,000,000'},
#   {'ISU_SRT_CD': '001140',
#    'ISU_ABBRV': '국보',
#    'TDD_CLSPRC': '1,270',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-15',
#    'FLUC_RT': '-1.17',
#    'MKTCAP': '88,468,288,900'},
#   {'ISU_SRT_CD': '001210',
#    'ISU_ABBRV': '금호전기',
#    'TDD_CLSPRC': '2,200',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-5',
#    'FLUC_RT': '-0.23',
#    'MKTCAP': '45,894,241,800'},
#   {'ISU_SRT_CD': '001380',
#    'ISU_ABBRV': 'SG글로벌',
#    'TDD_CLSPRC': '1,910',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-15',
#    'FLUC_RT': '-0.78',
#    'MKTCAP': '85,881,513,130'},
#   {'ISU_SRT_CD': '001420',
#    'ISU_ABBRV': '태원물산',
#    'TDD_CLSPRC': '5,540',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '400',
#    'FLUC_RT': '7.78',
#    'MKTCAP': '42,104,000,000'},
#   {'ISU_SRT_CD': '001620',
#    'ISU_ABBRV': '케이비아이동국실업',
#    'TDD_CLSPRC': '744',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '8',
#    'FLUC_RT': '1.09',
#    'MKTCAP': '64,940,786,976'},
#   {'ISU_SRT_CD': '001770',
#    'ISU_ABBRV': 'SHD',
#    'TDD_CLSPRC': '33,100',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '350',
#    'FLUC_RT': '1.07',
#    'MKTCAP': '40,212,461,800'},
#   {'ISU_SRT_CD': '002070',
#    'ISU_ABBRV': '비비안',
#    'TDD_CLSPRC': '2,640',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '10',
#    'FLUC_RT': '0.38',
#    'MKTCAP': '78,656,133,600'},
#   {'ISU_SRT_CD': '002420',
#    'ISU_ABBRV': '세기상사',
#    'TDD_CLSPRC': '10,700',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-150',
#    'FLUC_RT': '-1.38',
#    'MKTCAP': '45,757,694,000'},
#   {'ISU_SRT_CD': '002630',
#    'ISU_ABBRV': '오리엔트바이오',
#    'TDD_CLSPRC': '838',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '8',
#    'FLUC_RT': '0.96',
#    'MKTCAP': '99,372,558,190'},
#   {'ISU_SRT_CD': '002820',
#    'ISU_ABBRV': 'SUN&L',
#    'TDD_CLSPRC': '5,670',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-10',
#    'FLUC_RT': '-0.18',
#    'MKTCAP': '71,487,297,630'},
#   {'ISU_SRT_CD': '002870',
#    'ISU_ABBRV': '신풍제지',
#    'TDD_CLSPRC': '2,260',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-30',
#    'FLUC_RT': '-1.31',
#    'MKTCAP': '79,006,662,000'},
#   {'ISU_SRT_CD': '002920',
#    'ISU_ABBRV': '유성기업',
#    'TDD_CLSPRC': '3,275',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '150',
#    'FLUC_RT': '4.80',
#    'MKTCAP': '84,978,062,500'},
#   {'ISU_SRT_CD': '003010',
#    'ISU_ABBRV': '혜인',
#    'TDD_CLSPRC': '7,000',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '670',
#    'FLUC_RT': '10.58',
#    'MKTCAP': '88,989,229,000'},
#   {'ISU_SRT_CD': '003080',
#    'ISU_ABBRV': '성보화학',
#    'TDD_CLSPRC': '4,520',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-30',
#    'FLUC_RT': '-0.66',
#    'MKTCAP': '90,490,400,000'},
#   {'ISU_SRT_CD': '003680',
#    'ISU_ABBRV': '한성기업',
#    'TDD_CLSPRC': '9,340',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '80',
#    'FLUC_RT': '0.86',
#    'MKTCAP': '57,996,870,100'},
#   {'ISU_SRT_CD': '004100',
#    'ISU_ABBRV': '태양금속',
#    'TDD_CLSPRC': '1,455',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-35',
#    'FLUC_RT': '-2.35',
#    'MKTCAP': '53,398,500,000'},
#   {'ISU_SRT_CD': '004450',
#    'ISU_ABBRV': '삼화왕관',
#    'TDD_CLSPRC': '45,100',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '300',
#    'FLUC_RT': '0.67',
#    'MKTCAP': '97,162,492,900'},
#   {'ISU_SRT_CD': '004870',
#    'ISU_ABBRV': '티웨이홀딩스',
#    'TDD_CLSPRC': '825',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '90,314,537,775'},
#   {'ISU_SRT_CD': '004920',
#    'ISU_ABBRV': '씨아이테크',
#    'TDD_CLSPRC': '1,220',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '110',
#    'FLUC_RT': '9.91',
#    'MKTCAP': '48,741,097,180'},
#   {'ISU_SRT_CD': '005030',
#    'ISU_ABBRV': '부산주공',
#    'TDD_CLSPRC': '641',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '45',
#    'FLUC_RT': '7.55',
#    'MKTCAP': '42,289,080,164'},
#   {'ISU_SRT_CD': '005110',
#    'ISU_ABBRV': '한창',
#    'TDD_CLSPRC': '720',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-1',
#    'FLUC_RT': '-0.14',
#    'MKTCAP': '48,088,993,680'},
#   {'ISU_SRT_CD': '005360',
#    'ISU_ABBRV': '모나미',
#    'TDD_CLSPRC': '4,950',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-110',
#    'FLUC_RT': '-2.17',
#    'MKTCAP': '93,541,669,650'},
#   {'ISU_SRT_CD': '005820',
#    'ISU_ABBRV': '원림',
#    'TDD_CLSPRC': '22,800',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '350',
#    'FLUC_RT': '1.56',
#    'MKTCAP': '52,393,716,000'},
#   {'ISU_SRT_CD': '006200',
#    'ISU_ABBRV': '한국전자홀딩스',
#    'TDD_CLSPRC': '1,820',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '15',
#    'FLUC_RT': '0.83',
#    'MKTCAP': '85,181,707,520'},
#   {'ISU_SRT_CD': '006570',
#    'ISU_ABBRV': '대림통상',
#    'TDD_CLSPRC': '4,260',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-100',
#    'FLUC_RT': '-2.29',
#    'MKTCAP': '64,858,500,000'},
#   {'ISU_SRT_CD': '007120',
#    'ISU_ABBRV': '미래아이앤지',
#    'TDD_CLSPRC': '413',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '53,476,953,124'},
#   {'ISU_SRT_CD': '007610',
#    'ISU_ABBRV': '선도전기',
#    'TDD_CLSPRC': '3,000',
#    'FLUC_TP_CD': '0',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '54,000,000,000'},
#   {'ISU_SRT_CD': '008110',
#    'ISU_ABBRV': '대동전자',
#    'TDD_CLSPRC': '8,270',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '180',
#    'FLUC_RT': '2.22',
#    'MKTCAP': '86,755,996,690'},
#   {'ISU_SRT_CD': '008500',
#    'ISU_ABBRV': '일정실업',
#    'TDD_CLSPRC': '22,850',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '450',
#    'FLUC_RT': '2.01',
#    'MKTCAP': '27,420,000,000'},
#   {'ISU_SRT_CD': '008600',
#    'ISU_ABBRV': '윌비스',
#    'TDD_CLSPRC': '1,345',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '10',
#    'FLUC_RT': '0.75',
#    'MKTCAP': '90,432,472,455'},
#   {'ISU_SRT_CD': '008870',
#    'ISU_ABBRV': '금비',
#    'TDD_CLSPRC': '68,500',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '68,500,000,000'},
#   {'ISU_SRT_CD': '009140',
#    'ISU_ABBRV': '경인전자',
#    'TDD_CLSPRC': '29,650',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '300',
#    'FLUC_RT': '1.02',
#    'MKTCAP': '46,574,131,050'},
#   {'ISU_SRT_CD': '009310',
#    'ISU_ABBRV': '참엔지니어링',
#    'TDD_CLSPRC': '1,275',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '75,055,959,225'},
#   {'ISU_SRT_CD': '009770',
#    'ISU_ABBRV': '삼정펄프',
#    'TDD_CLSPRC': '30,100',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '200',
#    'FLUC_RT': '0.67',
#    'MKTCAP': '75,249,127,100'},
#   {'ISU_SRT_CD': '010100',
#    'ISU_ABBRV': '한국프랜지',
#    'TDD_CLSPRC': '3,190',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '60',
#    'FLUC_RT': '1.92',
#    'MKTCAP': '97,136,839,800'},
#   {'ISU_SRT_CD': '010400',
#    'ISU_ABBRV': '우진아이엔에스',
#    'TDD_CLSPRC': '7,650',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-30',
#    'FLUC_RT': '-0.39',
#    'MKTCAP': '58,308,300,000'},
#   {'ISU_SRT_CD': '010420',
#    'ISU_ABBRV': '한솔PNS',
#    'TDD_CLSPRC': '2,185',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-10',
#    'FLUC_RT': '-0.46',
#    'MKTCAP': '44,777,231,220'},
#   {'ISU_SRT_CD': '010640',
#    'ISU_ABBRV': '진양폴리',
#    'TDD_CLSPRC': '6,110',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-190',
#    'FLUC_RT': '-3.02',
#    'MKTCAP': '61,100,000,000'},
#   {'ISU_SRT_CD': '010660',
#    'ISU_ABBRV': '화천기계',
#    'TDD_CLSPRC': '3,295',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-20',
#    'FLUC_RT': '-0.60',
#    'MKTCAP': '72,490,000,000'},
#   {'ISU_SRT_CD': '010770',
#    'ISU_ABBRV': '평화홀딩스',
#    'TDD_CLSPRC': '3,770',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '5',
#    'FLUC_RT': '0.13',
#    'MKTCAP': '55,138,006,820'},
#   {'ISU_SRT_CD': '011230',
#    'ISU_ABBRV': '삼화전자',
#    'TDD_CLSPRC': '3,885',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-5',
#    'FLUC_RT': '-0.13',
#    'MKTCAP': '40,629,096,900'},
#   {'ISU_SRT_CD': '011300',
#    'ISU_ABBRV': '성안',
#    'TDD_CLSPRC': '655',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '51',
#    'FLUC_RT': '8.44',
#    'MKTCAP': '37,241,898,300'},
#   {'ISU_SRT_CD': '011330',
#    'ISU_ABBRV': '유니켐',
#    'TDD_CLSPRC': '1,335',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '97,039,096,770'},
#   {'ISU_SRT_CD': '011420',
#    'ISU_ABBRV': '갤럭시아에스엠',
#    'TDD_CLSPRC': '2,385',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '20',
#    'FLUC_RT': '0.85',
#    'MKTCAP': '65,705,900,940'},
#   {'ISU_SRT_CD': '012170',
#    'ISU_ABBRV': '아센디오',
#    'TDD_CLSPRC': '1,230',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-10',
#    'FLUC_RT': '-0.81',
#    'MKTCAP': '99,026,311,080'},
#   {'ISU_SRT_CD': '012280',
#    'ISU_ABBRV': '영화금속',
#    'TDD_CLSPRC': '1,735',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-5',
#    'FLUC_RT': '-0.29',
#    'MKTCAP': '92,639,466,175'},
#   {'ISU_SRT_CD': '012320',
#    'ISU_ABBRV': '경동인베스트',
#    'TDD_CLSPRC': '37,800',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-200',
#    'FLUC_RT': '-0.53',
#    'MKTCAP': '89,397,869,400'},
#   {'ISU_SRT_CD': '012600',
#    'ISU_ABBRV': '센트럴인사이트',
#    'TDD_CLSPRC': '2,490',
#    'FLUC_TP_CD': '0',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '37,500,376,080'},
#   {'ISU_SRT_CD': '013000',
#    'ISU_ABBRV': '세우글로벌',
#    'TDD_CLSPRC': '2,040',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '125',
#    'FLUC_RT': '6.53',
#    'MKTCAP': '58,558,263,240'},
#   {'ISU_SRT_CD': '013520',
#    'ISU_ABBRV': '화승코퍼레이션',
#    'TDD_CLSPRC': '1,760',
#    'FLUC_TP_CD': '3',
#    'STR_CMP_PRC': '0',
#    'FLUC_RT': '0.00',
#    'MKTCAP': '88,090,203,520'},
#   {'ISU_SRT_CD': '014130',
#    'ISU_ABBRV': '한익스프레스',
#    'TDD_CLSPRC': '5,820',
#    'FLUC_TP_CD': '2',
#    'STR_CMP_PRC': '-50',
#    'FLUC_RT': '-0.85',
#    'MKTCAP': '69,840,000,000'},
#   {'ISU_SRT_CD': '014440',
#    'ISU_ABBRV': '영보화학',
#    'TDD_CLSPRC': '4,920',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '10',
#    'FLUC_RT': '0.20',
#    'MKTCAP': '98,400,000,000'},
#   {'ISU_SRT_CD': '014910',
#    'ISU_ABBRV': '성문전자',
#    'TDD_CLSPRC': '2,405',
#    'FLUC_TP_CD': '1',
#    'STR_CMP_PRC': '15',
#    'FLUC_RT': '0.63',
#    'MKTCAP': '46,865,891,085'}],
#  'CURRENT_DATETIME': '2022.05.16 PM 04:32:50'}

# %% [markdown]
# * 할당된 json 파일을 df에 DataFrame 형식으로 할당하면 끝
# * 비록 하루 동안의 구성 종목이지만 그 수는 매우 많음
# * 따라서 상위 5개의 종목만 확인하고 제대로 데이터가 수집됐는지 검증하기

# %%
# json 형태의 결과값을 DataFrame 형식으로 df에 할당
df = pd.json_normalize(html_json['output'])
df.head()
# Out:
#   ISU_SRT_CD ISU_ABBRV TDD_CLSPRC FLUC_TP_CD STR_CMP_PRC FLUC_RT  \
# 0     005930      삼성전자     67,500          1         200    0.30
# 1     373220  LG에너지솔루션    407,500          2      -1,000   -0.24
# 2     000660    SK하이닉스    110,000          2        -500   -0.45
# 3     207940  삼성바이오로직스    832,000          2      -6,000   -0.72
# 4     035420     NAVER    282,000          1       1,000    0.36
#
#                 MKTCAP
# 0  402,960,322,125,000
# 1   95,355,000,000,000
# 2   80,080,260,150,000
# 3   59,216,768,000,000
# 4   46,261,841,970,000

# %% [markdown]
# '날짜', '종목 코드', '종목 이름', '지수 종류'만 수집하도록 데이터를 변경

# %%
html_json = html_json['output']
html_json
# Out:
# [{'ISU_SRT_CD': '005930',
#   'ISU_ABBRV': '삼성전자',
#   'TDD_CLSPRC': '67,500',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '200',
#   'FLUC_RT': '0.30',
#   'MKTCAP': '402,960,322,125,000'},
#  {'ISU_SRT_CD': '373220',
#   'ISU_ABBRV': 'LG에너지솔루션',
#   'TDD_CLSPRC': '407,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-0.24',
#   'MKTCAP': '95,355,000,000,000'},
#  {'ISU_SRT_CD': '000660',
#   'ISU_ABBRV': 'SK하이닉스',
#   'TDD_CLSPRC': '110,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-500',
#   'FLUC_RT': '-0.45',
#   'MKTCAP': '80,080,260,150,000'},
#  {'ISU_SRT_CD': '207940',
#   'ISU_ABBRV': '삼성바이오로직스',
#   'TDD_CLSPRC': '832,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-6,000',
#   'FLUC_RT': '-0.72',
#   'MKTCAP': '59,216,768,000,000'},
#  {'ISU_SRT_CD': '035420',
#   'ISU_ABBRV': 'NAVER',
#   'TDD_CLSPRC': '282,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,000',
#   'FLUC_RT': '0.36',
#   'MKTCAP': '46,261,841,970,000'},
#  {'ISU_SRT_CD': '006400',
#   'ISU_ABBRV': '삼성SDI',
#   'TDD_CLSPRC': '624,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '13,000',
#   'FLUC_RT': '2.13',
#   'MKTCAP': '42,909,066,720,000'},
#  {'ISU_SRT_CD': '035720',
#   'ISU_ABBRV': '카카오',
#   'TDD_CLSPRC': '88,500',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,200',
#   'FLUC_RT': '1.37',
#   'MKTCAP': '39,494,930,931,000'},
#  {'ISU_SRT_CD': '005380',
#   'ISU_ABBRV': '현대차',
#   'TDD_CLSPRC': '183,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-3,500',
#   'FLUC_RT': '-1.87',
#   'MKTCAP': '39,208,112,314,500'},
#  {'ISU_SRT_CD': '051910',
#   'ISU_ABBRV': 'LG화학',
#   'TDD_CLSPRC': '517,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-9,000',
#   'FLUC_RT': '-1.71',
#   'MKTCAP': '36,496,241,331,000'},
#  {'ISU_SRT_CD': '000270',
#   'ISU_ABBRV': '기아',
#   'TDD_CLSPRC': '83,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-900',
#   'FLUC_RT': '-1.07',
#   'MKTCAP': '33,847,839,474,500'},
#  {'ISU_SRT_CD': '005490',
#   'ISU_ABBRV': 'POSCO홀딩스',
#   'TDD_CLSPRC': '289,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-4,000',
#   'FLUC_RT': '-1.37',
#   'MKTCAP': '25,196,995,315,000'},
#  {'ISU_SRT_CD': '068270',
#   'ISU_ABBRV': '셀트리온',
#   'TDD_CLSPRC': '172,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-0.58',
#   'MKTCAP': '24,198,337,720,000'},
#  {'ISU_SRT_CD': '105560',
#   'ISU_ABBRV': 'KB금융',
#   'TDD_CLSPRC': '58,600',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '300',
#   'FLUC_RT': '0.51',
#   'MKTCAP': '24,163,856,148,400'},
#  {'ISU_SRT_CD': '055550',
#   'ISU_ABBRV': '신한지주',
#   'TDD_CLSPRC': '41,650',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.12',
#   'MKTCAP': '21,516,371,424,100'},
#  {'ISU_SRT_CD': '028260',
#   'ISU_ABBRV': '삼성물산',
#   'TDD_CLSPRC': '115,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-2,500',
#   'FLUC_RT': '-2.12',
#   'MKTCAP': '21,585,457,855,500'},
#  {'ISU_SRT_CD': '012330',
#   'ISU_ABBRV': '현대모비스',
#   'TDD_CLSPRC': '206,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-2,000',
#   'FLUC_RT': '-0.96',
#   'MKTCAP': '19,529,343,911,000'},
#  {'ISU_SRT_CD': '323410',
#   'ISU_ABBRV': '카카오뱅크',
#   'TDD_CLSPRC': '41,250',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '150',
#   'FLUC_RT': '0.36',
#   'MKTCAP': '19,643,103,026,250'},
#  {'ISU_SRT_CD': '034730',
#   'ISU_ABBRV': 'SK',
#   'TDD_CLSPRC': '261,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-8,000',
#   'FLUC_RT': '-2.97',
#   'MKTCAP': '19,352,974,869,000'},
#  {'ISU_SRT_CD': '066570',
#   'ISU_ABBRV': 'LG전자',
#   'TDD_CLSPRC': '115,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-0.86',
#   'MKTCAP': '18,901,322,517,000'},
#  {'ISU_SRT_CD': '096770',
#   'ISU_ABBRV': 'SK이노베이션',
#   'TDD_CLSPRC': '202,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-0.49',
#   'MKTCAP': '18,724,276,710,000'},
#  {'ISU_SRT_CD': '377300',
#   'ISU_ABBRV': '카카오페이',
#   'TDD_CLSPRC': '108,500',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '500',
#   'FLUC_RT': '0.46',
#   'MKTCAP': '14,369,597,973,500'},
#  {'ISU_SRT_CD': '015760',
#   'ISU_ABBRV': '한국전력',
#   'TDD_CLSPRC': '22,150',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-300',
#   'FLUC_RT': '-1.34',
#   'MKTCAP': '14,219,504,305,550'},
#  {'ISU_SRT_CD': '011200',
#   'ISU_ABBRV': 'HMM',
#   'TDD_CLSPRC': '28,900',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.17',
#   'MKTCAP': '14,133,241,434,400'},
#  {'ISU_SRT_CD': '086790',
#   'ISU_ABBRV': '하나금융지주',
#   'TDD_CLSPRC': '46,250',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-350',
#   'FLUC_RT': '-0.75',
#   'MKTCAP': '13,886,195,367,500'},
#  {'ISU_SRT_CD': '051900',
#   'ISU_ABBRV': 'LG생활건강',
#   'TDD_CLSPRC': '876,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-35,000',
#   'FLUC_RT': '-3.84',
#   'MKTCAP': '13,681,540,572,000'},
#  {'ISU_SRT_CD': '034020',
#   'ISU_ABBRV': '두산에너빌리티',
#   'TDD_CLSPRC': '20,800',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '350',
#   'FLUC_RT': '1.71',
#   'MKTCAP': '13,147,086,326,400'},
#  {'ISU_SRT_CD': '032830',
#   'ISU_ABBRV': '삼성생명',
#   'TDD_CLSPRC': '64,300',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-500',
#   'FLUC_RT': '-0.77',
#   'MKTCAP': '12,860,000,000,000'},
#  {'ISU_SRT_CD': '017670',
#   'ISU_ABBRV': 'SK텔레콤',
#   'TDD_CLSPRC': '57,800',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '800',
#   'FLUC_RT': '1.40',
#   'MKTCAP': '12,648,555,723,200'},
#  {'ISU_SRT_CD': '259960',
#   'ISU_ABBRV': '크래프톤',
#   'TDD_CLSPRC': '256,500',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '5,000',
#   'FLUC_RT': '1.99',
#   'MKTCAP': '12,586,979,542,500'},
#  {'ISU_SRT_CD': '009150',
#   'ISU_ABBRV': '삼성전기',
#   'TDD_CLSPRC': '166,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-2,000',
#   'FLUC_RT': '-1.19',
#   'MKTCAP': '12,436,500,384,000'},
#  {'ISU_SRT_CD': '329180',
#   'ISU_ABBRV': '현대중공업',
#   'TDD_CLSPRC': '137,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-2,500',
#   'FLUC_RT': '-1.79',
#   'MKTCAP': '12,206,303,450,000'},
#  {'ISU_SRT_CD': '010950',
#   'ISU_ABBRV': 'S-Oil',
#   'TDD_CLSPRC': '106,000',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '11,933,775,952,000'},
#  {'ISU_SRT_CD': '003550',
#   'ISU_ABBRV': 'LG',
#   'TDD_CLSPRC': '73,600',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-200',
#   'FLUC_RT': '-0.27',
#   'MKTCAP': '11,577,353,084,800'},
#  {'ISU_SRT_CD': '033780',
#   'ISU_ABBRV': 'KT&G',
#   'TDD_CLSPRC': '82,500',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '11,326,631,002,500'},
#  {'ISU_SRT_CD': '018260',
#   'ISU_ABBRV': '삼성에스디에스',
#   'TDD_CLSPRC': '147,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,500',
#   'FLUC_RT': '-1.01',
#   'MKTCAP': '11,413,225,500,000'},
#  {'ISU_SRT_CD': '316140',
#   'ISU_ABBRV': '우리금융지주',
#   'TDD_CLSPRC': '15,200',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '250',
#   'FLUC_RT': '1.67',
#   'MKTCAP': '11,066,520,344,800'},
#  {'ISU_SRT_CD': '010130',
#   'ISU_ABBRV': '고려아연',
#   'TDD_CLSPRC': '568,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-9,000',
#   'FLUC_RT': '-1.56',
#   'MKTCAP': '10,718,160,000,000'},
#  {'ISU_SRT_CD': '352820',
#   'ISU_ABBRV': '하이브',
#   'TDD_CLSPRC': '253,500',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,000',
#   'FLUC_RT': '0.40',
#   'MKTCAP': '10,483,083,604,500'},
#  {'ISU_SRT_CD': '003670',
#   'ISU_ABBRV': '포스코케미칼',
#   'TDD_CLSPRC': '134,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-0.74',
#   'MKTCAP': '10,380,071,480,000'},
#  {'ISU_SRT_CD': '003490',
#   'ISU_ABBRV': '대한항공',
#   'TDD_CLSPRC': '30,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '50',
#   'FLUC_RT': '0.17',
#   'MKTCAP': '10,434,624,750,000'},
#  {'ISU_SRT_CD': '090430',
#   'ISU_ABBRV': '아모레퍼시픽',
#   'TDD_CLSPRC': '172,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-6,500',
#   'FLUC_RT': '-3.63',
#   'MKTCAP': '10,090,000,927,500'},
#  {'ISU_SRT_CD': '302440',
#   'ISU_ABBRV': 'SK바이오사이언스',
#   'TDD_CLSPRC': '133,500',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,000',
#   'FLUC_RT': '0.75',
#   'MKTCAP': '10,250,670,141,000'},
#  {'ISU_SRT_CD': '000810',
#   'ISU_ABBRV': '삼성화재',
#   'TDD_CLSPRC': '204,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-2,000',
#   'FLUC_RT': '-0.97',
#   'MKTCAP': '9,664,466,748,000'},
#  {'ISU_SRT_CD': '036570',
#   'ISU_ABBRV': '엔씨소프트',
#   'TDD_CLSPRC': '432,500',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '7,500',
#   'FLUC_RT': '1.76',
#   'MKTCAP': '9,495,114,515,000'},
#  {'ISU_SRT_CD': '030200',
#   'ISU_ABBRV': 'KT',
#   'TDD_CLSPRC': '35,200',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-300',
#   'FLUC_RT': '-0.85',
#   'MKTCAP': '9,191,135,641,600'},
#  {'ISU_SRT_CD': '361610',
#   'ISU_ABBRV': 'SK아이이테크놀로지',
#   'TDD_CLSPRC': '125,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,500',
#   'FLUC_RT': '1.21',
#   'MKTCAP': '8,912,199,000,000'},
#  {'ISU_SRT_CD': '024110',
#   'ISU_ABBRV': '기업은행',
#   'TDD_CLSPRC': '11,350',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '100',
#   'FLUC_RT': '0.89',
#   'MKTCAP': '8,447,811,662,450'},
#  {'ISU_SRT_CD': '011070',
#   'ISU_ABBRV': 'LG이노텍',
#   'TDD_CLSPRC': '344,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-2,000',
#   'FLUC_RT': '-0.58',
#   'MKTCAP': '8,141,484,808,000'},
#  {'ISU_SRT_CD': '251270',
#   'ISU_ABBRV': '넷마블',
#   'TDD_CLSPRC': '93,100',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '100',
#   'FLUC_RT': '0.11',
#   'MKTCAP': '8,002,271,036,200'},
#  {'ISU_SRT_CD': '086280',
#   'ISU_ABBRV': '현대글로비스',
#   'TDD_CLSPRC': '205,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-5,000',
#   'FLUC_RT': '-2.38',
#   'MKTCAP': '7,706,250,000,000'},
#  {'ISU_SRT_CD': '402340',
#   'ISU_ABBRV': 'SK스퀘어',
#   'TDD_CLSPRC': '51,400',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '7,271,433,149,400'},
#  {'ISU_SRT_CD': '326030',
#   'ISU_ABBRV': 'SK바이오팜',
#   'TDD_CLSPRC': '91,600',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,500',
#   'FLUC_RT': '-1.61',
#   'MKTCAP': '7,173,493,700,000'},
#  {'ISU_SRT_CD': '011170',
#   'ISU_ABBRV': '롯데케미칼',
#   'TDD_CLSPRC': '197,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-0.51',
#   'MKTCAP': '6,752,257,543,000'},
#  {'ISU_SRT_CD': '009540',
#   'ISU_ABBRV': '한국조선해양',
#   'TDD_CLSPRC': '90,200',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,500',
#   'FLUC_RT': '-1.64',
#   'MKTCAP': '6,383,735,063,200'},
#  {'ISU_SRT_CD': '018880',
#   'ISU_ABBRV': '한온시스템',
#   'TDD_CLSPRC': '11,300',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '6,031,940,000,000'},
#  {'ISU_SRT_CD': '009830',
#   'ISU_ABBRV': '한화솔루션',
#   'TDD_CLSPRC': '31,850',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.16',
#   'MKTCAP': '6,092,220,129,450'},
#  {'ISU_SRT_CD': '034220',
#   'ISU_ABBRV': 'LG디스플레이',
#   'TDD_CLSPRC': '17,300',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '600',
#   'FLUC_RT': '3.59',
#   'MKTCAP': '6,190,211,610,000'},
#  {'ISU_SRT_CD': '032640',
#   'ISU_ABBRV': 'LG유플러스',
#   'TDD_CLSPRC': '13,950',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '50',
#   'FLUC_RT': '0.36',
#   'MKTCAP': '6,090,728,485,950'},
#  {'ISU_SRT_CD': '011790',
#   'ISU_ABBRV': 'SKC',
#   'TDD_CLSPRC': '153,500',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '500',
#   'FLUC_RT': '0.33',
#   'MKTCAP': '5,812,783,743,000'},
#  {'ISU_SRT_CD': '097950',
#   'ISU_ABBRV': 'CJ제일제당',
#   'TDD_CLSPRC': '388,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-13,500',
#   'FLUC_RT': '-3.36',
#   'MKTCAP': '5,841,024,168,000'},
#  {'ISU_SRT_CD': '035250',
#   'ISU_ABBRV': '강원랜드',
#   'TDD_CLSPRC': '26,450',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-250',
#   'FLUC_RT': '-0.94',
#   'MKTCAP': '5,658,726,225,000'},
#  {'ISU_SRT_CD': '004020',
#   'ISU_ABBRV': '현대제철',
#   'TDD_CLSPRC': '43,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-550',
#   'FLUC_RT': '-1.25',
#   'MKTCAP': '5,804,891,647,500'},
#  {'ISU_SRT_CD': '088980',
#   'ISU_ABBRV': '맥쿼리인프라',
#   'TDD_CLSPRC': '14,200',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.35',
#   'MKTCAP': '5,748,806,767,400'},
#  {'ISU_SRT_CD': '383220',
#   'ISU_ABBRV': 'F&F',
#   'TDD_CLSPRC': '140,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-0.71',
#   'MKTCAP': '5,382,144,037,500'},
#  {'ISU_SRT_CD': '000060',
#   'ISU_ABBRV': '메리츠화재',
#   'TDD_CLSPRC': '43,950',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-400',
#   'FLUC_RT': '-0.90',
#   'MKTCAP': '5,301,468,750,000'},
#  {'ISU_SRT_CD': '010140',
#   'ISU_ABBRV': '삼성중공업',
#   'TDD_CLSPRC': '5,910',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-120',
#   'FLUC_RT': '-1.99',
#   'MKTCAP': '5,200,800,000,000'},
#  {'ISU_SRT_CD': '028050',
#   'ISU_ABBRV': '삼성엔지니어링',
#   'TDD_CLSPRC': '26,050',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.19',
#   'MKTCAP': '5,105,800,000,000'},
#  {'ISU_SRT_CD': '021240',
#   'ISU_ABBRV': '코웨이',
#   'TDD_CLSPRC': '69,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-2,800',
#   'FLUC_RT': '-3.87',
#   'MKTCAP': '5,129,073,520,500'},
#  {'ISU_SRT_CD': '137310',
#   'ISU_ABBRV': '에스디바이오센서',
#   'TDD_CLSPRC': '46,650',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '50',
#   'FLUC_RT': '0.11',
#   'MKTCAP': '4,817,608,617,450'},
#  {'ISU_SRT_CD': '000720',
#   'ISU_ABBRV': '현대건설',
#   'TDD_CLSPRC': '44,650',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-100',
#   'FLUC_RT': '-0.22',
#   'MKTCAP': '4,972,034,907,250'},
#  {'ISU_SRT_CD': '006800',
#   'ISU_ABBRV': '미래에셋증권',
#   'TDD_CLSPRC': '7,970',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-90',
#   'FLUC_RT': '-1.12',
#   'MKTCAP': '4,904,071,771,760'},
#  {'ISU_SRT_CD': '138040',
#   'ISU_ABBRV': '메리츠금융지주',
#   'TDD_CLSPRC': '37,050',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-2.63',
#   'MKTCAP': '4,855,450,442,700'},
#  {'ISU_SRT_CD': '267250',
#   'ISU_ABBRV': 'HD현대',
#   'TDD_CLSPRC': '58,300',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '200',
#   'FLUC_RT': '0.34',
#   'MKTCAP': '4,605,296,855,500'},
#  {'ISU_SRT_CD': '011780',
#   'ISU_ABBRV': '금호석유',
#   'TDD_CLSPRC': '154,500',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '4,680,707,898,000'},
#  {'ISU_SRT_CD': '005830',
#   'ISU_ABBRV': 'DB손해보험',
#   'TDD_CLSPRC': '65,400',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-600',
#   'FLUC_RT': '-0.91',
#   'MKTCAP': '4,630,320,000,000'},
#  {'ISU_SRT_CD': '047810',
#   'ISU_ABBRV': '한국항공우주',
#   'TDD_CLSPRC': '47,200',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '750',
#   'FLUC_RT': '1.61',
#   'MKTCAP': '4,600,825,050,400'},
#  {'ISU_SRT_CD': '000100',
#   'ISU_ABBRV': '유한양행',
#   'TDD_CLSPRC': '60,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-400',
#   'FLUC_RT': '-0.66',
#   'MKTCAP': '4,430,504,298,000'},
#  {'ISU_SRT_CD': '078930',
#   'ISU_ABBRV': 'GS',
#   'TDD_CLSPRC': '45,100',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '550',
#   'FLUC_RT': '1.23',
#   'MKTCAP': '4,190,483,547,800'},
#  {'ISU_SRT_CD': '008560',
#   'ISU_ABBRV': '메리츠증권',
#   'TDD_CLSPRC': '6,620',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-210',
#   'FLUC_RT': '-3.07',
#   'MKTCAP': '4,367,813,632,980'},
#  {'ISU_SRT_CD': '161390',
#   'ISU_ABBRV': '한국타이어앤테크놀로지',
#   'TDD_CLSPRC': '34,900',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-700',
#   'FLUC_RT': '-1.97',
#   'MKTCAP': '4,323,239,908,100'},
#  {'ISU_SRT_CD': '241560',
#   'ISU_ABBRV': '두산밥캣',
#   'TDD_CLSPRC': '41,200',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '100',
#   'FLUC_RT': '0.24',
#   'MKTCAP': '4,130,265,639,200'},
#  {'ISU_SRT_CD': '003410',
#   'ISU_ABBRV': '쌍용C&E',
#   'TDD_CLSPRC': '8,190',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.61',
#   'MKTCAP': '4,126,610,083,050'},
#  {'ISU_SRT_CD': '002790',
#   'ISU_ABBRV': '아모레G',
#   'TDD_CLSPRC': '49,300',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,500',
#   'FLUC_RT': '-2.95',
#   'MKTCAP': '4,065,188,274,000'},
#  {'ISU_SRT_CD': '020150',
#   'ISU_ABBRV': '일진머티리얼즈',
#   'TDD_CLSPRC': '88,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-700',
#   'FLUC_RT': '-0.79',
#   'MKTCAP': '4,057,753,480,000'},
#  {'ISU_SRT_CD': '307950',
#   'ISU_ABBRV': '현대오토에버',
#   'TDD_CLSPRC': '138,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-0.72',
#   'MKTCAP': '3,784,509,516,000'},
#  {'ISU_SRT_CD': '071050',
#   'ISU_ABBRV': '한국금융지주',
#   'TDD_CLSPRC': '71,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,000',
#   'FLUC_RT': '1.43',
#   'MKTCAP': '3,956,545,432,000'},
#  {'ISU_SRT_CD': '036460',
#   'ISU_ABBRV': '한국가스공사',
#   'TDD_CLSPRC': '41,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-500',
#   'FLUC_RT': '-1.20',
#   'MKTCAP': '3,784,833,000,000'},
#  {'ISU_SRT_CD': '029780',
#   'ISU_ABBRV': '삼성카드',
#   'TDD_CLSPRC': '33,250',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-0.45',
#   'MKTCAP': '3,852,308,125,750'},
#  {'ISU_SRT_CD': '180640',
#   'ISU_ABBRV': '한진칼',
#   'TDD_CLSPRC': '57,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-400',
#   'FLUC_RT': '-0.70',
#   'MKTCAP': '3,805,392,048,000'},
#  {'ISU_SRT_CD': '271560',
#   'ISU_ABBRV': '오리온',
#   'TDD_CLSPRC': '91,100',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-4,300',
#   'FLUC_RT': '-4.51',
#   'MKTCAP': '3,601,741,625,200'},
#  {'ISU_SRT_CD': '128940',
#   'ISU_ABBRV': '한미약품',
#   'TDD_CLSPRC': '302,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-7,500',
#   'FLUC_RT': '-2.42',
#   'MKTCAP': '3,726,186,227,500'},
#  {'ISU_SRT_CD': '006360',
#   'ISU_ABBRV': 'GS건설',
#   'TDD_CLSPRC': '41,900',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-400',
#   'FLUC_RT': '-0.95',
#   'MKTCAP': '3,585,864,431,000'},
#  {'ISU_SRT_CD': '028670',
#   'ISU_ABBRV': '팬오션',
#   'TDD_CLSPRC': '6,820',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-90',
#   'FLUC_RT': '-1.30',
#   'MKTCAP': '3,645,764,071,840'},
#  {'ISU_SRT_CD': '004990',
#   'ISU_ABBRV': '롯데지주',
#   'TDD_CLSPRC': '34,300',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '3,598,386,829,100'},
#  {'ISU_SRT_CD': '139480',
#   'ISU_ABBRV': '이마트',
#   'TDD_CLSPRC': '129,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-2,000',
#   'FLUC_RT': '-1.52',
#   'MKTCAP': '3,609,918,560,500'},
#  {'ISU_SRT_CD': '016360',
#   'ISU_ABBRV': '삼성증권',
#   'TDD_CLSPRC': '39,600',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-0.38',
#   'MKTCAP': '3,536,280,000,000'},
#  {'ISU_SRT_CD': '008930',
#   'ISU_ABBRV': '한미사이언스',
#   'TDD_CLSPRC': '49,050',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,650',
#   'FLUC_RT': '-3.25',
#   'MKTCAP': '3,365,991,700,200'},
#  {'ISU_SRT_CD': '005940',
#   'ISU_ABBRV': 'NH투자증권',
#   'TDD_CLSPRC': '10,650',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-1.39',
#   'MKTCAP': '3,532,242,058,650'},
#  {'ISU_SRT_CD': '282330',
#   'ISU_ABBRV': 'BGF리테일',
#   'TDD_CLSPRC': '187,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '5,000',
#   'FLUC_RT': '2.75',
#   'MKTCAP': '3,232,090,422,000'},
#  {'ISU_SRT_CD': '010620',
#   'ISU_ABBRV': '현대미포조선',
#   'TDD_CLSPRC': '81,800',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,200',
#   'FLUC_RT': '-1.45',
#   'MKTCAP': '3,267,267,788,200'},
#  {'ISU_SRT_CD': '008770',
#   'ISU_ABBRV': '호텔신라',
#   'TDD_CLSPRC': '80,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-500',
#   'FLUC_RT': '-0.62',
#   'MKTCAP': '3,159,473,740,500'},
#  {'ISU_SRT_CD': '272210',
#   'ISU_ABBRV': '한화시스템',
#   'TDD_CLSPRC': '15,850',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-200',
#   'FLUC_RT': '-1.25',
#   'MKTCAP': '2,994,372,315,650'},
#  {'ISU_SRT_CD': '030000',
#   'ISU_ABBRV': '제일기획',
#   'TDD_CLSPRC': '26,250',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '650',
#   'FLUC_RT': '2.54',
#   'MKTCAP': '3,019,832,156,250'},
#  {'ISU_SRT_CD': '002380',
#   'ISU_ABBRV': 'KCC',
#   'TDD_CLSPRC': '355,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '5,500',
#   'FLUC_RT': '1.57',
#   'MKTCAP': '3,154,697,205,000'},
#  {'ISU_SRT_CD': '007070',
#   'ISU_ABBRV': 'GS리테일',
#   'TDD_CLSPRC': '29,400',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-300',
#   'FLUC_RT': '-1.01',
#   'MKTCAP': '3,078,706,906,800'},
#  {'ISU_SRT_CD': '000990',
#   'ISU_ABBRV': 'DB하이텍',
#   'TDD_CLSPRC': '67,700',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '800',
#   'FLUC_RT': '1.20',
#   'MKTCAP': '3,005,784,407,600'},
#  {'ISU_SRT_CD': '047050',
#   'ISU_ABBRV': '포스코인터내셔널',
#   'TDD_CLSPRC': '24,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.20',
#   'MKTCAP': '3,022,691,150,500'},
#  {'ISU_SRT_CD': '047040',
#   'ISU_ABBRV': '대우건설',
#   'TDD_CLSPRC': '6,750',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-10',
#   'FLUC_RT': '-0.15',
#   'MKTCAP': '2,805,452,806,500'},
#  {'ISU_SRT_CD': '052690',
#   'ISU_ABBRV': '한전기술',
#   'TDD_CLSPRC': '75,800',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '2,300',
#   'FLUC_RT': '3.13',
#   'MKTCAP': '2,897,076,000,000'},
#  {'ISU_SRT_CD': '001450',
#   'ISU_ABBRV': '현대해상',
#   'TDD_CLSPRC': '31,350',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '150',
#   'FLUC_RT': '0.48',
#   'MKTCAP': '2,802,690,000,000'},
#  {'ISU_SRT_CD': '014680',
#   'ISU_ABBRV': '한솔케미칼',
#   'TDD_CLSPRC': '244,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,000',
#   'FLUC_RT': '0.41',
#   'MKTCAP': '2,765,787,580,000'},
#  {'ISU_SRT_CD': '000120',
#   'ISU_ABBRV': 'CJ대한통운',
#   'TDD_CLSPRC': '121,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,500',
#   'FLUC_RT': '-1.22',
#   'MKTCAP': '2,760,293,624,000'},
#  {'ISU_SRT_CD': '012450',
#   'ISU_ABBRV': '한화에어로스페이스',
#   'TDD_CLSPRC': '56,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,500',
#   'FLUC_RT': '2.75',
#   'MKTCAP': '2,835,280,000,000'},
#  {'ISU_SRT_CD': '138930',
#   'ISU_ABBRV': 'BNK금융지주',
#   'TDD_CLSPRC': '7,890',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '2,571,629,090,940'},
#  {'ISU_SRT_CD': '023530',
#   'ISU_ABBRV': '롯데쇼핑',
#   'TDD_CLSPRC': '94,300',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-200',
#   'FLUC_RT': '-0.21',
#   'MKTCAP': '2,667,629,596,500'},
#  {'ISU_SRT_CD': '026960',
#   'ISU_ABBRV': '동서',
#   'TDD_CLSPRC': '26,750',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-0.56',
#   'MKTCAP': '2,666,975,000,000'},
#  {'ISU_SRT_CD': '000080',
#   'ISU_ABBRV': '하이트진로',
#   'TDD_CLSPRC': '37,800',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '350',
#   'FLUC_RT': '0.93',
#   'MKTCAP': '2,651,050,495,800'},
#  {'ISU_SRT_CD': '010060',
#   'ISU_ABBRV': 'OCI',
#   'TDD_CLSPRC': '110,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '500',
#   'FLUC_RT': '0.46',
#   'MKTCAP': '2,623,430,810,000'},
#  {'ISU_SRT_CD': '012750',
#   'ISU_ABBRV': '에스원',
#   'TDD_CLSPRC': '68,700',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '2,610,543,528,600'},
#  {'ISU_SRT_CD': '042660',
#   'ISU_ABBRV': '대우조선해양',
#   'TDD_CLSPRC': '25,300',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-750',
#   'FLUC_RT': '-2.88',
#   'MKTCAP': '2,714,453,925,700'},
#  {'ISU_SRT_CD': '088350',
#   'ISU_ABBRV': '한화생명',
#   'TDD_CLSPRC': '2,875',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-15',
#   'FLUC_RT': '-0.52',
#   'MKTCAP': '2,497,023,750,000'},
#  {'ISU_SRT_CD': '112610',
#   'ISU_ABBRV': '씨에스윈드',
#   'TDD_CLSPRC': '57,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,100',
#   'FLUC_RT': '-1.88',
#   'MKTCAP': '2,424,855,672,500'},
#  {'ISU_SRT_CD': '004170',
#   'ISU_ABBRV': '신세계',
#   'TDD_CLSPRC': '246,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-500',
#   'FLUC_RT': '-0.20',
#   'MKTCAP': '2,421,914,526,000'},
#  {'ISU_SRT_CD': '039490',
#   'ISU_ABBRV': '키움증권',
#   'TDD_CLSPRC': '93,300',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '2,446,280,562,900'},
#  {'ISU_SRT_CD': '001040',
#   'ISU_ABBRV': 'CJ',
#   'TDD_CLSPRC': '85,100',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,900',
#   'FLUC_RT': '-2.18',
#   'MKTCAP': '2,482,962,529,800'},
#  {'ISU_SRT_CD': '204320',
#   'ISU_ABBRV': '만도',
#   'TDD_CLSPRC': '54,200',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-200',
#   'FLUC_RT': '-0.37',
#   'MKTCAP': '2,545,075,904,000'},
#  {'ISU_SRT_CD': '285130',
#   'ISU_ABBRV': 'SK케미칼',
#   'TDD_CLSPRC': '128,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-500',
#   'FLUC_RT': '-0.39',
#   'MKTCAP': '2,255,459,840,000'},
#  {'ISU_SRT_CD': '336260',
#   'ISU_ABBRV': '두산퓨얼셀',
#   'TDD_CLSPRC': '34,550',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '250',
#   'FLUC_RT': '0.73',
#   'MKTCAP': '2,262,808,233,300'},
#  {'ISU_SRT_CD': '336370',
#   'ISU_ABBRV': '솔루스첨단소재',
#   'TDD_CLSPRC': '71,900',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-800',
#   'FLUC_RT': '-1.10',
#   'MKTCAP': '2,199,403,600,200'},
#  {'ISU_SRT_CD': '001440',
#   'ISU_ABBRV': '대한전선',
#   'TDD_CLSPRC': '1,865',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-5',
#   'FLUC_RT': '-0.27',
#   'MKTCAP': '2,320,942,161,785'},
#  {'ISU_SRT_CD': '016380',
#   'ISU_ABBRV': 'KG스틸',
#   'TDD_CLSPRC': '23,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-600',
#   'FLUC_RT': '-2.54',
#   'MKTCAP': '2,300,204,631,000'},
#  {'ISU_SRT_CD': '006280',
#   'ISU_ABBRV': '녹십자',
#   'TDD_CLSPRC': '187,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-6,000',
#   'FLUC_RT': '-3.11',
#   'MKTCAP': '2,185,382,606,000'},
#  {'ISU_SRT_CD': '000880',
#   'ISU_ABBRV': '한화',
#   'TDD_CLSPRC': '29,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-100',
#   'FLUC_RT': '-0.34',
#   'MKTCAP': '2,211,282,682,500'},
#  {'ISU_SRT_CD': '375500',
#   'ISU_ABBRV': 'DL이앤씨',
#   'TDD_CLSPRC': '55,400',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-4,200',
#   'FLUC_RT': '-7.05',
#   'MKTCAP': '2,143,626,714,200'},
#  {'ISU_SRT_CD': '298050',
#   'ISU_ABBRV': '효성첨단소재',
#   'TDD_CLSPRC': '466,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-3,500',
#   'FLUC_RT': '-0.74',
#   'MKTCAP': '2,089,895,742,000'},
#  {'ISU_SRT_CD': '069620',
#   'ISU_ABBRV': '대웅제약',
#   'TDD_CLSPRC': '182,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-0.54',
#   'MKTCAP': '2,114,549,937,500'},
#  {'ISU_SRT_CD': '004000',
#   'ISU_ABBRV': '롯데정밀화학',
#   'TDD_CLSPRC': '81,300',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-800',
#   'FLUC_RT': '-0.97',
#   'MKTCAP': '2,097,540,000,000'},
#  {'ISU_SRT_CD': '111770',
#   'ISU_ABBRV': '영원무역',
#   'TDD_CLSPRC': '47,450',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-550',
#   'FLUC_RT': '-1.15',
#   'MKTCAP': '2,102,579,156,600'},
#  {'ISU_SRT_CD': '064350',
#   'ISU_ABBRV': '현대로템',
#   'TDD_CLSPRC': '19,050',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.26',
#   'MKTCAP': '2,079,160,681,650'},
#  {'ISU_SRT_CD': '081660',
#   'ISU_ABBRV': '휠라홀딩스',
#   'TDD_CLSPRC': '32,050',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-0.47',
#   'MKTCAP': '1,947,108,715,100'},
#  {'ISU_SRT_CD': '298020',
#   'ISU_ABBRV': '효성티앤씨',
#   'TDD_CLSPRC': '405,000',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '1,752,711,210,000'},
#  {'ISU_SRT_CD': '069960',
#   'ISU_ABBRV': '현대백화점',
#   'TDD_CLSPRC': '75,300',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-700',
#   'FLUC_RT': '-0.92',
#   'MKTCAP': '1,762,203,807,300'},
#  {'ISU_SRT_CD': '079550',
#   'ISU_ABBRV': 'LIG넥스원',
#   'TDD_CLSPRC': '86,800',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,300',
#   'FLUC_RT': '1.52',
#   'MKTCAP': '1,909,600,000,000'},
#  {'ISU_SRT_CD': '093370',
#   'ISU_ABBRV': '후성',
#   'TDD_CLSPRC': '19,650',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '600',
#   'FLUC_RT': '3.15',
#   'MKTCAP': '1,819,723,993,350'},
#  {'ISU_SRT_CD': '051600',
#   'ISU_ABBRV': '한전KPS',
#   'TDD_CLSPRC': '38,700',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '600',
#   'FLUC_RT': '1.57',
#   'MKTCAP': '1,741,500,000,000'},
#  {'ISU_SRT_CD': '004370',
#   'ISU_ABBRV': '농심',
#   'TDD_CLSPRC': '300,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-6,000',
#   'FLUC_RT': '-1.96',
#   'MKTCAP': '1,824,792,600,000'},
#  {'ISU_SRT_CD': '005300',
#   'ISU_ABBRV': '롯데칠성',
#   'TDD_CLSPRC': '199,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-500',
#   'FLUC_RT': '-0.25',
#   'MKTCAP': '1,851,137,358,000'},
#  {'ISU_SRT_CD': '006260',
#   'ISU_ABBRV': 'LS',
#   'TDD_CLSPRC': '56,600',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-900',
#   'FLUC_RT': '-1.57',
#   'MKTCAP': '1,822,520,000,000'},
#  {'ISU_SRT_CD': '011210',
#   'ISU_ABBRV': '현대위아',
#   'TDD_CLSPRC': '64,800',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,300',
#   'FLUC_RT': '-1.97',
#   'MKTCAP': '1,762,241,378,400'},
#  {'ISU_SRT_CD': '001230',
#   'ISU_ABBRV': '동국제강',
#   'TDD_CLSPRC': '19,050',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-300',
#   'FLUC_RT': '-1.55',
#   'MKTCAP': '1,817,993,639,850'},
#  {'ISU_SRT_CD': '003090',
#   'ISU_ABBRV': '대웅',
#   'TDD_CLSPRC': '29,950',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '200',
#   'FLUC_RT': '0.67',
#   'MKTCAP': '1,741,352,301,000'},
#  {'ISU_SRT_CD': '004800',
#   'ISU_ABBRV': '효성',
#   'TDD_CLSPRC': '83,400',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '400',
#   'FLUC_RT': '0.48',
#   'MKTCAP': '1,757,323,485,000'},
#  {'ISU_SRT_CD': '353200',
#   'ISU_ABBRV': '대덕전자',
#   'TDD_CLSPRC': '31,800',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,100',
#   'FLUC_RT': '3.58',
#   'MKTCAP': '1,571,458,215,000'},
#  {'ISU_SRT_CD': '089860',
#   'ISU_ABBRV': '롯데렌탈',
#   'TDD_CLSPRC': '43,650',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '1,599,076,849,950'},
#  {'ISU_SRT_CD': '120110',
#   'ISU_ABBRV': '코오롱인더',
#   'TDD_CLSPRC': '62,600',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '400',
#   'FLUC_RT': '0.64',
#   'MKTCAP': '1,722,695,096,600'},
#  {'ISU_SRT_CD': '175330',
#   'ISU_ABBRV': 'JB금융지주',
#   'TDD_CLSPRC': '8,790',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-70',
#   'FLUC_RT': '-0.79',
#   'MKTCAP': '1,731,479,638,260'},
#  {'ISU_SRT_CD': '019170',
#   'ISU_ABBRV': '신풍제약',
#   'TDD_CLSPRC': '29,100',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-750',
#   'FLUC_RT': '-2.51',
#   'MKTCAP': '1,541,863,209,000'},
#  {'ISU_SRT_CD': '001120',
#   'ISU_ABBRV': 'LX인터내셔널',
#   'TDD_CLSPRC': '39,600',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,150',
#   'FLUC_RT': '2.99',
#   'MKTCAP': '1,534,896,000,000'},
#  {'ISU_SRT_CD': '007310',
#   'ISU_ABBRV': '오뚜기',
#   'TDD_CLSPRC': '456,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-9,000',
#   'FLUC_RT': '-1.94',
#   'MKTCAP': '1,674,423,336,000'},
#  {'ISU_SRT_CD': '009240',
#   'ISU_ABBRV': '한샘',
#   'TDD_CLSPRC': '70,400',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,400',
#   'FLUC_RT': '-1.95',
#   'MKTCAP': '1,656,788,531,200'},
#  {'ISU_SRT_CD': '010780',
#   'ISU_ABBRV': '아이에스동서',
#   'TDD_CLSPRC': '53,600',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '600',
#   'FLUC_RT': '1.13',
#   'MKTCAP': '1,655,843,681,600'},
#  {'ISU_SRT_CD': '014820',
#   'ISU_ABBRV': '동원시스템즈',
#   'TDD_CLSPRC': '57,400',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,600',
#   'FLUC_RT': '-2.71',
#   'MKTCAP': '1,675,414,791,400'},
#  {'ISU_SRT_CD': '005070',
#   'ISU_ABBRV': '코스모신소재',
#   'TDD_CLSPRC': '55,100',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '500',
#   'FLUC_RT': '0.92',
#   'MKTCAP': '1,657,787,583,900'},
#  {'ISU_SRT_CD': '271940',
#   'ISU_ABBRV': '일진하이솔루스',
#   'TDD_CLSPRC': '40,800',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '650',
#   'FLUC_RT': '1.62',
#   'MKTCAP': '1,481,578,152,000'},
#  {'ISU_SRT_CD': '300720',
#   'ISU_ABBRV': '한일시멘트',
#   'TDD_CLSPRC': '20,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-200',
#   'FLUC_RT': '-0.97',
#   'MKTCAP': '1,419,861,570,000'},
#  {'ISU_SRT_CD': '139130',
#   'ISU_ABBRV': 'DGB금융지주',
#   'TDD_CLSPRC': '8,850',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '1,496,940,622,050'},
#  {'ISU_SRT_CD': '178920',
#   'ISU_ABBRV': 'PI첨단소재',
#   'TDD_CLSPRC': '47,950',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-0.31',
#   'MKTCAP': '1,408,115,139,900'},
#  {'ISU_SRT_CD': '181710',
#   'ISU_ABBRV': 'NHN',
#   'TDD_CLSPRC': '35,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-0.42',
#   'MKTCAP': '1,331,885,982,500'},
#  {'ISU_SRT_CD': '249420',
#   'ISU_ABBRV': '일동제약',
#   'TDD_CLSPRC': '50,900',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,600',
#   'FLUC_RT': '-3.05',
#   'MKTCAP': '1,364,287,206,500'},
#  {'ISU_SRT_CD': '017800',
#   'ISU_ABBRV': '현대엘리베이',
#   'TDD_CLSPRC': '35,800',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '300',
#   'FLUC_RT': '0.85',
#   'MKTCAP': '1,461,183,837,800'},
#  {'ISU_SRT_CD': '020560',
#   'ISU_ABBRV': '아시아나항공',
#   'TDD_CLSPRC': '19,950',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-200',
#   'FLUC_RT': '-0.99',
#   'MKTCAP': '1,484,514,691,800'},
#  {'ISU_SRT_CD': '042670',
#   'ISU_ABBRV': '현대두산인프라코어',
#   'TDD_CLSPRC': '6,760',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '170',
#   'FLUC_RT': '2.58',
#   'MKTCAP': '1,334,801,627,120'},
#  {'ISU_SRT_CD': '042700',
#   'ISU_ABBRV': '한미반도체',
#   'TDD_CLSPRC': '15,050',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '50',
#   'FLUC_RT': '0.33',
#   'MKTCAP': '1,488,742,297,700'},
#  {'ISU_SRT_CD': '010120',
#   'ISU_ABBRV': 'LS ELECTRIC',
#   'TDD_CLSPRC': '50,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '50',
#   'FLUC_RT': '0.10',
#   'MKTCAP': '1,500,000,000,000'},
#  {'ISU_SRT_CD': '330590',
#   'ISU_ABBRV': '롯데리츠',
#   'TDD_CLSPRC': '5,840',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-120',
#   'FLUC_RT': '-2.01',
#   'MKTCAP': '1,418,938,282,560'},
#  {'ISU_SRT_CD': '365550',
#   'ISU_ABBRV': 'ESR켄달스퀘어리츠',
#   'TDD_CLSPRC': '6,980',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-220',
#   'FLUC_RT': '-3.06',
#   'MKTCAP': '1,487,361,220,000'},
#  {'ISU_SRT_CD': '000150',
#   'ISU_ABBRV': '두산',
#   'TDD_CLSPRC': '89,600',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,900',
#   'FLUC_RT': '2.17',
#   'MKTCAP': '1,480,535,616,000'},
#  {'ISU_SRT_CD': '000210',
#   'ISU_ABBRV': 'DL',
#   'TDD_CLSPRC': '65,400',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '3,200',
#   'FLUC_RT': '5.14',
#   'MKTCAP': '1,370,514,813,600'},
#  {'ISU_SRT_CD': '000240',
#   'ISU_ABBRV': '한국앤컴퍼니',
#   'TDD_CLSPRC': '14,400',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-100',
#   'FLUC_RT': '-0.69',
#   'MKTCAP': '1,367,067,456,000'},
#  {'ISU_SRT_CD': '363280',
#   'ISU_ABBRV': '티와이홀딩스',
#   'TDD_CLSPRC': '25,100',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.20',
#   'MKTCAP': '1,278,324,626,800'},
#  {'ISU_SRT_CD': '003690',
#   'ISU_ABBRV': '코리안리',
#   'TDD_CLSPRC': '9,770',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-100',
#   'FLUC_RT': '-1.01',
#   'MKTCAP': '1,176,006,263,320'},
#  {'ISU_SRT_CD': '073240',
#   'ISU_ABBRV': '금호타이어',
#   'TDD_CLSPRC': '4,215',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-25',
#   'FLUC_RT': '-0.59',
#   'MKTCAP': '1,210,802,109,705'},
#  {'ISU_SRT_CD': '185750',
#   'ISU_ABBRV': '종근당',
#   'TDD_CLSPRC': '98,200',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '300',
#   'FLUC_RT': '0.31',
#   'MKTCAP': '1,177,225,331,600'},
#  {'ISU_SRT_CD': '195870',
#   'ISU_ABBRV': '해성디에스',
#   'TDD_CLSPRC': '71,600',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,200',
#   'FLUC_RT': '1.70',
#   'MKTCAP': '1,217,200,000,000'},
#  {'ISU_SRT_CD': '248070',
#   'ISU_ABBRV': '솔루엠',
#   'TDD_CLSPRC': '25,650',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,400',
#   'FLUC_RT': '5.77',
#   'MKTCAP': '1,282,642,383,150'},
#  {'ISU_SRT_CD': '018670',
#   'ISU_ABBRV': 'SK가스',
#   'TDD_CLSPRC': '136,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '9,000',
#   'FLUC_RT': '7.09',
#   'MKTCAP': '1,255,313,184,000'},
#  {'ISU_SRT_CD': '031430',
#   'ISU_ABBRV': '신세계인터내셔날',
#   'TDD_CLSPRC': '32,150',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '250',
#   'FLUC_RT': '0.78',
#   'MKTCAP': '1,147,755,000,000'},
#  {'ISU_SRT_CD': '032350',
#   'ISU_ABBRV': '롯데관광개발',
#   'TDD_CLSPRC': '16,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-300',
#   'FLUC_RT': '-1.84',
#   'MKTCAP': '1,151,663,296,000'},
#  {'ISU_SRT_CD': '039130',
#   'ISU_ABBRV': '하나투어',
#   'TDD_CLSPRC': '82,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,100',
#   'FLUC_RT': '-1.32',
#   'MKTCAP': '1,143,013,170,000'},
#  {'ISU_SRT_CD': '005850',
#   'ISU_ABBRV': '에스엘',
#   'TDD_CLSPRC': '26,750',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-350',
#   'FLUC_RT': '-1.29',
#   'MKTCAP': '1,289,437,659,750'},
#  {'ISU_SRT_CD': '009900',
#   'ISU_ABBRV': '명신산업',
#   'TDD_CLSPRC': '22,750',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-100',
#   'FLUC_RT': '-0.44',
#   'MKTCAP': '1,193,695,525,750'},
#  {'ISU_SRT_CD': '012510',
#   'ISU_ABBRV': '더존비즈온',
#   'TDD_CLSPRC': '41,350',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '150',
#   'FLUC_RT': '0.36',
#   'MKTCAP': '1,256,328,118,400'},
#  {'ISU_SRT_CD': '000670',
#   'ISU_ABBRV': '영풍',
#   'TDD_CLSPRC': '684,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '4,000',
#   'FLUC_RT': '0.59',
#   'MKTCAP': '1,259,955,360,000'},
#  {'ISU_SRT_CD': '001740',
#   'ISU_ABBRV': 'SK네트웍스',
#   'TDD_CLSPRC': '4,820',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-20',
#   'FLUC_RT': '-0.41',
#   'MKTCAP': '1,196,264,458,540'},
#  {'ISU_SRT_CD': '003240',
#   'ISU_ABBRV': '태광산업',
#   'TDD_CLSPRC': '1,015,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-0.10',
#   'MKTCAP': '1,130,101,000,000'},
#  {'ISU_SRT_CD': '381970',
#   'ISU_ABBRV': '케이카',
#   'TDD_CLSPRC': '27,300',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '300',
#   'FLUC_RT': '1.11',
#   'MKTCAP': '1,312,762,350,900'},
#  {'ISU_SRT_CD': '268280',
#   'ISU_ABBRV': '미원에스씨',
#   'TDD_CLSPRC': '207,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-2,500',
#   'FLUC_RT': '-1.19',
#   'MKTCAP': '1,055,700,000,000'},
#  {'ISU_SRT_CD': '003530',
#   'ISU_ABBRV': '한화투자증권',
#   'TDD_CLSPRC': '4,770',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '10',
#   'FLUC_RT': '0.21',
#   'MKTCAP': '1,023,392,886,750'},
#  {'ISU_SRT_CD': '294870',
#   'ISU_ABBRV': 'HDC현대산업개발',
#   'TDD_CLSPRC': '14,950',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-0.99',
#   'MKTCAP': '985,314,583,500'},
#  {'ISU_SRT_CD': '344820',
#   'ISU_ABBRV': 'KCC글라스',
#   'TDD_CLSPRC': '62,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-200',
#   'FLUC_RT': '-0.32',
#   'MKTCAP': '990,171,744,000'},
#  {'ISU_SRT_CD': '079160',
#   'ISU_ABBRV': 'CJ CGV',
#   'TDD_CLSPRC': '27,300',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-0.55',
#   'MKTCAP': '1,114,747,042,500'},
#  {'ISU_SRT_CD': '082640',
#   'ISU_ABBRV': '동양생명',
#   'TDD_CLSPRC': '6,650',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-60',
#   'FLUC_RT': '-0.89',
#   'MKTCAP': '1,073,034,590,250'},
#  {'ISU_SRT_CD': '089590',
#   'ISU_ABBRV': '제주항공',
#   'TDD_CLSPRC': '21,350',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-450',
#   'FLUC_RT': '-2.06',
#   'MKTCAP': '1,062,368,911,800'},
#  {'ISU_SRT_CD': '105630',
#   'ISU_ABBRV': '한세실업',
#   'TDD_CLSPRC': '26,550',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-0.56',
#   'MKTCAP': '1,062,000,000,000'},
#  {'ISU_SRT_CD': '114090',
#   'ISU_ABBRV': 'GKL',
#   'TDD_CLSPRC': '15,050',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-300',
#   'FLUC_RT': '-1.95',
#   'MKTCAP': '930,927,833,500'},
#  {'ISU_SRT_CD': '161890',
#   'ISU_ABBRV': '한국콜마',
#   'TDD_CLSPRC': '45,850',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,200',
#   'FLUC_RT': '-2.55',
#   'MKTCAP': '1,049,102,103,000'},
#  {'ISU_SRT_CD': '192820',
#   'ISU_ABBRV': '코스맥스',
#   'TDD_CLSPRC': '82,400',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-2,700',
#   'FLUC_RT': '-3.17',
#   'MKTCAP': '935,199,541,600'},
#  {'ISU_SRT_CD': '214320',
#   'ISU_ABBRV': '이노션',
#   'TDD_CLSPRC': '49,200',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '100',
#   'FLUC_RT': '0.20',
#   'MKTCAP': '984,000,000,000'},
#  {'ISU_SRT_CD': '241590',
#   'ISU_ABBRV': '화승엔터프라이즈',
#   'TDD_CLSPRC': '16,550',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-550',
#   'FLUC_RT': '-3.22',
#   'MKTCAP': '1,002,607,457,050'},
#  {'ISU_SRT_CD': '014830',
#   'ISU_ABBRV': '유니드',
#   'TDD_CLSPRC': '122,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-5,500',
#   'FLUC_RT': '-4.31',
#   'MKTCAP': '1,084,560,846,000'},
#  {'ISU_SRT_CD': '016710',
#   'ISU_ABBRV': '대성홀딩스',
#   'TDD_CLSPRC': '58,700',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-200',
#   'FLUC_RT': '-0.34',
#   'MKTCAP': '944,451,243,300'},
#  {'ISU_SRT_CD': '017390',
#   'ISU_ABBRV': '서울가스',
#   'TDD_CLSPRC': '183,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,500',
#   'FLUC_RT': '-0.81',
#   'MKTCAP': '917,500,000,000'},
#  {'ISU_SRT_CD': '023590',
#   'ISU_ABBRV': '다우기술',
#   'TDD_CLSPRC': '20,900',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '300',
#   'FLUC_RT': '1.46',
#   'MKTCAP': '937,712,295,300'},
#  {'ISU_SRT_CD': '034120',
#   'ISU_ABBRV': 'SBS',
#   'TDD_CLSPRC': '52,400',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,900',
#   'FLUC_RT': '3.76',
#   'MKTCAP': '956,435,296,800'},
#  {'ISU_SRT_CD': '036420',
#   'ISU_ABBRV': '콘텐트리중앙',
#   'TDD_CLSPRC': '48,800',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '2,400',
#   'FLUC_RT': '5.17',
#   'MKTCAP': '930,742,782,400'},
#  {'ISU_SRT_CD': '004490',
#   'ISU_ABBRV': '세방전지',
#   'TDD_CLSPRC': '73,800',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,100',
#   'FLUC_RT': '1.51',
#   'MKTCAP': '1,033,200,000,000'},
#  {'ISU_SRT_CD': '005250',
#   'ISU_ABBRV': '녹십자홀딩스',
#   'TDD_CLSPRC': '21,900',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-0.68',
#   'MKTCAP': '1,029,917,799,000'},
#  {'ISU_SRT_CD': '006650',
#   'ISU_ABBRV': '대한유화',
#   'TDD_CLSPRC': '153,500',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,500',
#   'FLUC_RT': '0.99',
#   'MKTCAP': '997,750,000,000'},
#  {'ISU_SRT_CD': '007700',
#   'ISU_ABBRV': 'F&F홀딩스',
#   'TDD_CLSPRC': '25,900',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-250',
#   'FLUC_RT': '-0.96',
#   'MKTCAP': '1,013,062,105,300'},
#  {'ISU_SRT_CD': '009420',
#   'ISU_ABBRV': '한올바이오파마',
#   'TDD_CLSPRC': '18,150',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-300',
#   'FLUC_RT': '-1.63',
#   'MKTCAP': '948,167,579,700'},
#  {'ISU_SRT_CD': '013890',
#   'ISU_ABBRV': '지누스',
#   'TDD_CLSPRC': '63,800',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '800',
#   'FLUC_RT': '1.27',
#   'MKTCAP': '1,008,068,710,000'},
#  {'ISU_SRT_CD': '348950',
#   'ISU_ABBRV': '제이알글로벌리츠',
#   'TDD_CLSPRC': '5,780',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-110',
#   'FLUC_RT': '-1.87',
#   'MKTCAP': '957,168,000,000'},
#  {'ISU_SRT_CD': '395400',
#   'ISU_ABBRV': 'SK리츠',
#   'TDD_CLSPRC': '7,050',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-80',
#   'FLUC_RT': '-1.12',
#   'MKTCAP': '1,092,894,750,600'},
#  {'ISU_SRT_CD': '001800',
#   'ISU_ABBRV': '오리온홀딩스',
#   'TDD_CLSPRC': '14,700',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.34',
#   'MKTCAP': '920,887,703,400'},
#  {'ISU_SRT_CD': '272450',
#   'ISU_ABBRV': '진에어',
#   'TDD_CLSPRC': '18,050',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.28',
#   'MKTCAP': '942,210,000,000'},
#  {'ISU_SRT_CD': '267260',
#   'ISU_ABBRV': '현대일렉트릭',
#   'TDD_CLSPRC': '24,050',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,150',
#   'FLUC_RT': '5.02',
#   'MKTCAP': '866,933,596,750'},
#  {'ISU_SRT_CD': '003850',
#   'ISU_ABBRV': '보령',
#   'TDD_CLSPRC': '12,700',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-200',
#   'FLUC_RT': '-1.55',
#   'MKTCAP': '872,363,000,000'},
#  {'ISU_SRT_CD': '280360',
#   'ISU_ABBRV': '롯데제과',
#   'TDD_CLSPRC': '124,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-0.80',
#   'MKTCAP': '795,672,908,000'},
#  {'ISU_SRT_CD': '284740',
#   'ISU_ABBRV': '쿠쿠홈시스',
#   'TDD_CLSPRC': '34,700',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-450',
#   'FLUC_RT': '-1.28',
#   'MKTCAP': '778,575,351,000'},
#  {'ISU_SRT_CD': '298000',
#   'ISU_ABBRV': '효성화학',
#   'TDD_CLSPRC': '224,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,000',
#   'FLUC_RT': '0.45',
#   'MKTCAP': '714,588,224,000'},
#  {'ISU_SRT_CD': '383800',
#   'ISU_ABBRV': 'LX홀딩스',
#   'TDD_CLSPRC': '9,960',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-40',
#   'FLUC_RT': '-0.40',
#   'MKTCAP': '759,755,672,400'},
#  {'ISU_SRT_CD': '069260',
#   'ISU_ABBRV': 'TKG휴켐스',
#   'TDD_CLSPRC': '22,100',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-0.67',
#   'MKTCAP': '903,416,794,800'},
#  {'ISU_SRT_CD': '097520',
#   'ISU_ABBRV': '엠씨넥스',
#   'TDD_CLSPRC': '43,100',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-200',
#   'FLUC_RT': '-0.46',
#   'MKTCAP': '774,784,219,200'},
#  {'ISU_SRT_CD': '103140',
#   'ISU_ABBRV': '풍산',
#   'TDD_CLSPRC': '32,100',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-350',
#   'FLUC_RT': '-1.08',
#   'MKTCAP': '899,579,323,800'},
#  {'ISU_SRT_CD': '145720',
#   'ISU_ABBRV': '덴티움',
#   'TDD_CLSPRC': '71,200',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-300',
#   'FLUC_RT': '-0.42',
#   'MKTCAP': '788,100,696,000'},
#  {'ISU_SRT_CD': '192080',
#   'ISU_ABBRV': '더블유게임즈',
#   'TDD_CLSPRC': '49,100',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-500',
#   'FLUC_RT': '-1.01',
#   'MKTCAP': '902,188,048,200'},
#  {'ISU_SRT_CD': '020000',
#   'ISU_ABBRV': '한섬',
#   'TDD_CLSPRC': '35,400',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-450',
#   'FLUC_RT': '-1.26',
#   'MKTCAP': '871,902,000,000'},
#  {'ISU_SRT_CD': '025540',
#   'ISU_ABBRV': '한국단자',
#   'TDD_CLSPRC': '69,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-100',
#   'FLUC_RT': '-0.14',
#   'MKTCAP': '718,635,000,000'},
#  {'ISU_SRT_CD': '025860',
#   'ISU_ABBRV': '남해화학',
#   'TDD_CLSPRC': '14,650',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '250',
#   'FLUC_RT': '1.74',
#   'MKTCAP': '727,795,049,950'},
#  {'ISU_SRT_CD': '057050',
#   'ISU_ABBRV': '현대홈쇼핑',
#   'TDD_CLSPRC': '60,000',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '720,000,000,000'},
#  {'ISU_SRT_CD': '005090',
#   'ISU_ABBRV': 'SGC에너지',
#   'TDD_CLSPRC': '49,700',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-400',
#   'FLUC_RT': '-0.80',
#   'MKTCAP': '729,447,098,800'},
#  {'ISU_SRT_CD': '005440',
#   'ISU_ABBRV': '현대그린푸드',
#   'TDD_CLSPRC': '9,100',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-70',
#   'FLUC_RT': '-0.76',
#   'MKTCAP': '889,110,786,200'},
#  {'ISU_SRT_CD': '005610',
#   'ISU_ABBRV': 'SPC삼립',
#   'TDD_CLSPRC': '89,800',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,400',
#   'FLUC_RT': '-1.54',
#   'MKTCAP': '774,885,008,200'},
#  {'ISU_SRT_CD': '005880',
#   'ISU_ABBRV': '대한해운',
#   'TDD_CLSPRC': '2,740',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '10',
#   'FLUC_RT': '0.37',
#   'MKTCAP': '874,546,240,400'},
#  {'ISU_SRT_CD': '006040',
#   'ISU_ABBRV': '동원산업',
#   'TDD_CLSPRC': '239,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-6,500',
#   'FLUC_RT': '-2.65',
#   'MKTCAP': '878,956,199,000'},
#  {'ISU_SRT_CD': '006120',
#   'ISU_ABBRV': 'SK디스커버리',
#   'TDD_CLSPRC': '42,200',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '803,397,481,000'},
#  {'ISU_SRT_CD': '007340',
#   'ISU_ABBRV': '디티알오토모티브',
#   'TDD_CLSPRC': '76,400',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-300',
#   'FLUC_RT': '-0.39',
#   'MKTCAP': '763,541,982,000'},
#  {'ISU_SRT_CD': '009450',
#   'ISU_ABBRV': '경동나비엔',
#   'TDD_CLSPRC': '52,700',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '300',
#   'FLUC_RT': '0.57',
#   'MKTCAP': '767,764,798,400'},
#  {'ISU_SRT_CD': '010050',
#   'ISU_ABBRV': '우리종금',
#   'TDD_CLSPRC': '875',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '3',
#   'FLUC_RT': '0.34',
#   'MKTCAP': '764,927,980,250'},
#  {'ISU_SRT_CD': '011000',
#   'ISU_ABBRV': '진원생명과학',
#   'TDD_CLSPRC': '11,150',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '50',
#   'FLUC_RT': '0.45',
#   'MKTCAP': '866,115,297,300'},
#  {'ISU_SRT_CD': '000070',
#   'ISU_ABBRV': '삼양홀딩스',
#   'TDD_CLSPRC': '85,000',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,200',
#   'FLUC_RT': '-1.39',
#   'MKTCAP': '727,963,035,000'},
#  {'ISU_SRT_CD': '000640',
#   'ISU_ABBRV': '동아쏘시오홀딩스',
#   'TDD_CLSPRC': '115,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,500',
#   'FLUC_RT': '1.32',
#   'MKTCAP': '730,124,995,000'},
#  {'ISU_SRT_CD': '001680',
#   'ISU_ABBRV': '대상',
#   'TDD_CLSPRC': '24,700',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-500',
#   'FLUC_RT': '-1.98',
#   'MKTCAP': '855,806,217,500'},
#  {'ISU_SRT_CD': '002840',
#   'ISU_ABBRV': '미원상사',
#   'TDD_CLSPRC': '168,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,000',
#   'FLUC_RT': '-0.59',
#   'MKTCAP': '837,445,000,000'},
#  {'ISU_SRT_CD': '003000',
#   'ISU_ABBRV': '부광약품',
#   'TDD_CLSPRC': '11,700',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-200',
#   'FLUC_RT': '-1.68',
#   'MKTCAP': '831,437,673,300'},
#  {'ISU_SRT_CD': '003230',
#   'ISU_ABBRV': '삼양식품',
#   'TDD_CLSPRC': '96,200',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-2,000',
#   'FLUC_RT': '-2.04',
#   'MKTCAP': '724,676,043,000'},
#  {'ISU_SRT_CD': '003520',
#   'ISU_ABBRV': '영진약품',
#   'TDD_CLSPRC': '4,850',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-40',
#   'FLUC_RT': '-0.82',
#   'MKTCAP': '887,029,745,350'},
#  {'ISU_SRT_CD': '003540',
#   'ISU_ABBRV': '대신증권',
#   'TDD_CLSPRC': '17,250',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.29',
#   'MKTCAP': '875,841,150,000'},
#  {'ISU_SRT_CD': '267270',
#   'ISU_ABBRV': '현대건설기계',
#   'TDD_CLSPRC': '40,300',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '1,600',
#   'FLUC_RT': '4.13',
#   'MKTCAP': '793,941,957,900'},
#  {'ISU_SRT_CD': '286940',
#   'ISU_ABBRV': '롯데정보통신',
#   'TDD_CLSPRC': '34,100',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,400',
#   'FLUC_RT': '-3.94',
#   'MKTCAP': '525,014,887,100'},
#  {'ISU_SRT_CD': '004430',
#   'ISU_ABBRV': '송원산업',
#   'TDD_CLSPRC': '26,400',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,500',
#   'FLUC_RT': '-5.38',
#   'MKTCAP': '633,600,000,000'},
#  {'ISU_SRT_CD': '306200',
#   'ISU_ABBRV': '세아제강',
#   'TDD_CLSPRC': '183,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '3,500',
#   'FLUC_RT': '1.95',
#   'MKTCAP': '519,042,900,000'},
#  {'ISU_SRT_CD': '071840',
#   'ISU_ABBRV': '롯데하이마트',
#   'TDD_CLSPRC': '23,350',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.21',
#   'MKTCAP': '551,240,075,200'},
#  {'ISU_SRT_CD': '084010',
#   'ISU_ABBRV': '대한제강',
#   'TDD_CLSPRC': '21,750',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-550',
#   'FLUC_RT': '-2.47',
#   'MKTCAP': '536,066,464,500'},
#  {'ISU_SRT_CD': '085620',
#   'ISU_ABBRV': '미래에셋생명',
#   'TDD_CLSPRC': '3,970',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '702,754,270,330'},
#  {'ISU_SRT_CD': '093050',
#   'ISU_ABBRV': 'LF',
#   'TDD_CLSPRC': '19,750',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '400',
#   'FLUC_RT': '2.07',
#   'MKTCAP': '577,490,000,000'},
#  {'ISU_SRT_CD': '097230',
#   'ISU_ABBRV': 'HJ중공업',
#   'TDD_CLSPRC': '7,950',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '30',
#   'FLUC_RT': '0.38',
#   'MKTCAP': '662,030,533,950'},
#  {'ISU_SRT_CD': '115390',
#   'ISU_ABBRV': '락앤락',
#   'TDD_CLSPRC': '10,300',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '530,969,264,200'},
#  {'ISU_SRT_CD': '145990',
#   'ISU_ABBRV': '삼양사',
#   'TDD_CLSPRC': '55,900',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-900',
#   'FLUC_RT': '-1.58',
#   'MKTCAP': '576,521,799,100'},
#  {'ISU_SRT_CD': '161000',
#   'ISU_ABBRV': '애경케미칼',
#   'TDD_CLSPRC': '10,550',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '100',
#   'FLUC_RT': '0.96',
#   'MKTCAP': '513,243,879,950'},
#  {'ISU_SRT_CD': '170900',
#   'ISU_ABBRV': '동아에스티',
#   'TDD_CLSPRC': '69,600',
#   'FLUC_TP_CD': '1',
# ...
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '60,992,495,900'},
#  {'ISU_SRT_CD': '025890',
#   'ISU_ABBRV': '한국주강',
#   'TDD_CLSPRC': '4,200',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '45',
#   'FLUC_RT': '1.08',
#   'MKTCAP': '47,498,887,800'},
#  {'ISU_SRT_CD': '027970',
#   'ISU_ABBRV': '세하',
#   'TDD_CLSPRC': '1,740',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '20',
#   'FLUC_RT': '1.16',
#   'MKTCAP': '100,159,614,780'},
#  {'ISU_SRT_CD': '030720',
#   'ISU_ABBRV': '동원수산',
#   'TDD_CLSPRC': '13,100',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '60,964,845,500'},
#  {'ISU_SRT_CD': '030790',
#   'ISU_ABBRV': '비케이탑스',
#   'TDD_CLSPRC': '1,385',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-70',
#   'FLUC_RT': '-4.81',
#   'MKTCAP': '23,490,140,150'},
#  {'ISU_SRT_CD': '033250',
#   'ISU_ABBRV': '체시스',
#   'TDD_CLSPRC': '1,345',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '20',
#   'FLUC_RT': '1.51',
#   'MKTCAP': '43,040,000,000'},
#  {'ISU_SRT_CD': '041650',
#   'ISU_ABBRV': '상신브레이크',
#   'TDD_CLSPRC': '4,050',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '30',
#   'FLUC_RT': '0.75',
#   'MKTCAP': '86,959,372,500'},
#  {'ISU_SRT_CD': '044380',
#   'ISU_ABBRV': '주연테크',
#   'TDD_CLSPRC': '1,080',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '10',
#   'FLUC_RT': '0.93',
#   'MKTCAP': '63,935,183,520'},
#  {'ISU_SRT_CD': '049800',
#   'ISU_ABBRV': '우진플라임',
#   'TDD_CLSPRC': '4,755',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '20',
#   'FLUC_RT': '0.42',
#   'MKTCAP': '95,100,000,000'},
#  {'ISU_SRT_CD': '051630',
#   'ISU_ABBRV': '진양화학',
#   'TDD_CLSPRC': '5,690',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '50',
#   'FLUC_RT': '0.89',
#   'MKTCAP': '68,280,000,000'},
#  {'ISU_SRT_CD': '058730',
#   'ISU_ABBRV': '다스코',
#   'TDD_CLSPRC': '5,270',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '365',
#   'FLUC_RT': '7.44',
#   'MKTCAP': '88,939,476,470'},
#  {'ISU_SRT_CD': '058860',
#   'ISU_ABBRV': 'KTis',
#   'TDD_CLSPRC': '2,655',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '5',
#   'FLUC_RT': '0.19',
#   'MKTCAP': '92,399,310,000'},
#  {'ISU_SRT_CD': '069640',
#   'ISU_ABBRV': '한세엠케이',
#   'TDD_CLSPRC': '4,130',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-5',
#   'FLUC_RT': '-0.12',
#   'MKTCAP': '53,315,499,860'},
#  {'ISU_SRT_CD': '069730',
#   'ISU_ABBRV': 'DSR제강',
#   'TDD_CLSPRC': '6,740',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '240',
#   'FLUC_RT': '3.69',
#   'MKTCAP': '97,056,000,000'},
#  {'ISU_SRT_CD': '071950',
#   'ISU_ABBRV': '코아스',
#   'TDD_CLSPRC': '1,110',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '34,307,003,100'},
#  {'ISU_SRT_CD': '072130',
#   'ISU_ABBRV': '유엔젤',
#   'TDD_CLSPRC': '4,580',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '60,435,179,320'},
#  {'ISU_SRT_CD': '084670',
#   'ISU_ABBRV': '동양고속',
#   'TDD_CLSPRC': '18,950',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-250',
#   'FLUC_RT': '-1.30',
#   'MKTCAP': '54,871,032,550'},
#  {'ISU_SRT_CD': '084870',
#   'ISU_ABBRV': 'TBH글로벌',
#   'TDD_CLSPRC': '2,275',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '45',
#   'FLUC_RT': '2.02',
#   'MKTCAP': '47,449,263,225'},
#  {'ISU_SRT_CD': '085310',
#   'ISU_ABBRV': '엔케이',
#   'TDD_CLSPRC': '1,170',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-20',
#   'FLUC_RT': '-1.68',
#   'MKTCAP': '93,580,521,840'},
#  {'ISU_SRT_CD': '088790',
#   'ISU_ABBRV': '진도',
#   'TDD_CLSPRC': '3,985',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '25',
#   'FLUC_RT': '0.63',
#   'MKTCAP': '49,604,259,840'},
#  {'ISU_SRT_CD': '090080',
#   'ISU_ABBRV': '평화산업',
#   'TDD_CLSPRC': '1,780',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-5',
#   'FLUC_RT': '-0.28',
#   'MKTCAP': '97,726,021,020'},
#  {'ISU_SRT_CD': '090370',
#   'ISU_ABBRV': '메타랩스',
#   'TDD_CLSPRC': '849',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '2',
#   'FLUC_RT': '0.24',
#   'MKTCAP': '63,270,407,352'},
#  {'ISU_SRT_CD': '092780',
#   'ISU_ABBRV': '동양피스톤',
#   'TDD_CLSPRC': '6,720',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '280',
#   'FLUC_RT': '4.35',
#   'MKTCAP': '88,492,051,200'},
#  {'ISU_SRT_CD': '093240',
#   'ISU_ABBRV': '형지엘리트',
#   'TDD_CLSPRC': '2,050',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '50',
#   'FLUC_RT': '2.50',
#   'MKTCAP': '63,867,335,900'},
#  {'ISU_SRT_CD': '100220',
#   'ISU_ABBRV': '비상교육',
#   'TDD_CLSPRC': '7,700',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '50',
#   'FLUC_RT': '0.65',
#   'MKTCAP': '100,074,905,700'},
#  {'ISU_SRT_CD': '109070',
#   'ISU_ABBRV': '컨버즈',
#   'TDD_CLSPRC': '4,100',
#   'FLUC_TP_CD': '0',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '71,952,027,500'},
#  {'ISU_SRT_CD': '119650',
#   'ISU_ABBRV': 'KC코트렐',
#   'TDD_CLSPRC': '5,560',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '90',
#   'FLUC_RT': '1.65',
#   'MKTCAP': '97,856,000,000'},
#  {'ISU_SRT_CD': '123700',
#   'ISU_ABBRV': 'SJM',
#   'TDD_CLSPRC': '4,465',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '85',
#   'FLUC_RT': '1.94',
#   'MKTCAP': '69,675,869,570'},
#  {'ISU_SRT_CD': '145210',
#   'ISU_ABBRV': '다이나믹디자인',
#   'TDD_CLSPRC': '238',
#   'FLUC_TP_CD': '0',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '37,672,840,548'},
#  {'ISU_SRT_CD': '378850',
#   'ISU_ABBRV': '화승알앤에이',
#   'TDD_CLSPRC': '4,535',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '86,136,080,305'},
#  {'ISU_SRT_CD': '140910',
#   'ISU_ABBRV': '에이리츠',
#   'TDD_CLSPRC': '7,780',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '60',
#   'FLUC_RT': '0.78',
#   'MKTCAP': '34,722,388,960'},
#  {'ISU_SRT_CD': '145270',
#   'ISU_ABBRV': '케이탑리츠',
#   'TDD_CLSPRC': '1,480',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-15',
#   'FLUC_RT': '-1.00',
#   'MKTCAP': '71,129,945,520'},
#  {'ISU_SRT_CD': '204210',
#   'ISU_ABBRV': '모두투어리츠',
#   'TDD_CLSPRC': '5,200',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-60',
#   'FLUC_RT': '-1.14',
#   'MKTCAP': '40,699,438,000'},
#  {'ISU_SRT_CD': '338100',
#   'ISU_ABBRV': 'NH프라임리츠',
#   'TDD_CLSPRC': '5,030',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-70',
#   'FLUC_RT': '-1.37',
#   'MKTCAP': '93,859,800,000'},
#  {'ISU_SRT_CD': '155900',
#   'ISU_ABBRV': '바다로19호',
#   'TDD_CLSPRC': '3,270',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-5',
#   'FLUC_RT': '-0.15',
#   'MKTCAP': '49,704,013,080'},
#  {'ISU_SRT_CD': '000040',
#   'ISU_ABBRV': 'KR모터스',
#   'TDD_CLSPRC': '859',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '4',
#   'FLUC_RT': '0.47',
#   'MKTCAP': '82,581,999,112'},
#  {'ISU_SRT_CD': '000590',
#   'ISU_ABBRV': 'CS홀딩스',
#   'TDD_CLSPRC': '68,100',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '500',
#   'FLUC_RT': '0.74',
#   'MKTCAP': '78,620,224,200'},
#  {'ISU_SRT_CD': '000650',
#   'ISU_ABBRV': '천일고속',
#   'TDD_CLSPRC': '67,600',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '100',
#   'FLUC_RT': '0.15',
#   'MKTCAP': '96,615,272,000'},
#  {'ISU_SRT_CD': '000760',
#   'ISU_ABBRV': '이화산업',
#   'TDD_CLSPRC': '18,400',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '100',
#   'FLUC_RT': '0.55',
#   'MKTCAP': '51,520,000,000'},
#  {'ISU_SRT_CD': '000850',
#   'ISU_ABBRV': '화천기공',
#   'TDD_CLSPRC': '36,200',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '450',
#   'FLUC_RT': '1.26',
#   'MKTCAP': '79,640,000,000'},
#  {'ISU_SRT_CD': '000950',
#   'ISU_ABBRV': '전방',
#   'TDD_CLSPRC': '53,500',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1,200',
#   'FLUC_RT': '-2.19',
#   'MKTCAP': '89,880,000,000'},
#  {'ISU_SRT_CD': '001140',
#   'ISU_ABBRV': '국보',
#   'TDD_CLSPRC': '1,270',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-15',
#   'FLUC_RT': '-1.17',
#   'MKTCAP': '88,468,288,900'},
#  {'ISU_SRT_CD': '001210',
#   'ISU_ABBRV': '금호전기',
#   'TDD_CLSPRC': '2,200',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-5',
#   'FLUC_RT': '-0.23',
#   'MKTCAP': '45,894,241,800'},
#  {'ISU_SRT_CD': '001380',
#   'ISU_ABBRV': 'SG글로벌',
#   'TDD_CLSPRC': '1,910',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-15',
#   'FLUC_RT': '-0.78',
#   'MKTCAP': '85,881,513,130'},
#  {'ISU_SRT_CD': '001420',
#   'ISU_ABBRV': '태원물산',
#   'TDD_CLSPRC': '5,540',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '400',
#   'FLUC_RT': '7.78',
#   'MKTCAP': '42,104,000,000'},
#  {'ISU_SRT_CD': '001620',
#   'ISU_ABBRV': '케이비아이동국실업',
#   'TDD_CLSPRC': '744',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '8',
#   'FLUC_RT': '1.09',
#   'MKTCAP': '64,940,786,976'},
#  {'ISU_SRT_CD': '001770',
#   'ISU_ABBRV': 'SHD',
#   'TDD_CLSPRC': '33,100',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '350',
#   'FLUC_RT': '1.07',
#   'MKTCAP': '40,212,461,800'},
#  {'ISU_SRT_CD': '002070',
#   'ISU_ABBRV': '비비안',
#   'TDD_CLSPRC': '2,640',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '10',
#   'FLUC_RT': '0.38',
#   'MKTCAP': '78,656,133,600'},
#  {'ISU_SRT_CD': '002420',
#   'ISU_ABBRV': '세기상사',
#   'TDD_CLSPRC': '10,700',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-150',
#   'FLUC_RT': '-1.38',
#   'MKTCAP': '45,757,694,000'},
#  {'ISU_SRT_CD': '002630',
#   'ISU_ABBRV': '오리엔트바이오',
#   'TDD_CLSPRC': '838',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '8',
#   'FLUC_RT': '0.96',
#   'MKTCAP': '99,372,558,190'},
#  {'ISU_SRT_CD': '002820',
#   'ISU_ABBRV': 'SUN&L',
#   'TDD_CLSPRC': '5,670',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-10',
#   'FLUC_RT': '-0.18',
#   'MKTCAP': '71,487,297,630'},
#  {'ISU_SRT_CD': '002870',
#   'ISU_ABBRV': '신풍제지',
#   'TDD_CLSPRC': '2,260',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-30',
#   'FLUC_RT': '-1.31',
#   'MKTCAP': '79,006,662,000'},
#  {'ISU_SRT_CD': '002920',
#   'ISU_ABBRV': '유성기업',
#   'TDD_CLSPRC': '3,275',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '150',
#   'FLUC_RT': '4.80',
#   'MKTCAP': '84,978,062,500'},
#  {'ISU_SRT_CD': '003010',
#   'ISU_ABBRV': '혜인',
#   'TDD_CLSPRC': '7,000',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '670',
#   'FLUC_RT': '10.58',
#   'MKTCAP': '88,989,229,000'},
#  {'ISU_SRT_CD': '003080',
#   'ISU_ABBRV': '성보화학',
#   'TDD_CLSPRC': '4,520',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-30',
#   'FLUC_RT': '-0.66',
#   'MKTCAP': '90,490,400,000'},
#  {'ISU_SRT_CD': '003680',
#   'ISU_ABBRV': '한성기업',
#   'TDD_CLSPRC': '9,340',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '80',
#   'FLUC_RT': '0.86',
#   'MKTCAP': '57,996,870,100'},
#  {'ISU_SRT_CD': '004100',
#   'ISU_ABBRV': '태양금속',
#   'TDD_CLSPRC': '1,455',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-35',
#   'FLUC_RT': '-2.35',
#   'MKTCAP': '53,398,500,000'},
#  {'ISU_SRT_CD': '004450',
#   'ISU_ABBRV': '삼화왕관',
#   'TDD_CLSPRC': '45,100',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '300',
#   'FLUC_RT': '0.67',
#   'MKTCAP': '97,162,492,900'},
#  {'ISU_SRT_CD': '004870',
#   'ISU_ABBRV': '티웨이홀딩스',
#   'TDD_CLSPRC': '825',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '90,314,537,775'},
#  {'ISU_SRT_CD': '004920',
#   'ISU_ABBRV': '씨아이테크',
#   'TDD_CLSPRC': '1,220',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '110',
#   'FLUC_RT': '9.91',
#   'MKTCAP': '48,741,097,180'},
#  {'ISU_SRT_CD': '005030',
#   'ISU_ABBRV': '부산주공',
#   'TDD_CLSPRC': '641',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '45',
#   'FLUC_RT': '7.55',
#   'MKTCAP': '42,289,080,164'},
#  {'ISU_SRT_CD': '005110',
#   'ISU_ABBRV': '한창',
#   'TDD_CLSPRC': '720',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-1',
#   'FLUC_RT': '-0.14',
#   'MKTCAP': '48,088,993,680'},
#  {'ISU_SRT_CD': '005360',
#   'ISU_ABBRV': '모나미',
#   'TDD_CLSPRC': '4,950',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-110',
#   'FLUC_RT': '-2.17',
#   'MKTCAP': '93,541,669,650'},
#  {'ISU_SRT_CD': '005820',
#   'ISU_ABBRV': '원림',
#   'TDD_CLSPRC': '22,800',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '350',
#   'FLUC_RT': '1.56',
#   'MKTCAP': '52,393,716,000'},
#  {'ISU_SRT_CD': '006200',
#   'ISU_ABBRV': '한국전자홀딩스',
#   'TDD_CLSPRC': '1,820',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '15',
#   'FLUC_RT': '0.83',
#   'MKTCAP': '85,181,707,520'},
#  {'ISU_SRT_CD': '006570',
#   'ISU_ABBRV': '대림통상',
#   'TDD_CLSPRC': '4,260',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-100',
#   'FLUC_RT': '-2.29',
#   'MKTCAP': '64,858,500,000'},
#  {'ISU_SRT_CD': '007120',
#   'ISU_ABBRV': '미래아이앤지',
#   'TDD_CLSPRC': '413',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '53,476,953,124'},
#  {'ISU_SRT_CD': '007610',
#   'ISU_ABBRV': '선도전기',
#   'TDD_CLSPRC': '3,000',
#   'FLUC_TP_CD': '0',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '54,000,000,000'},
#  {'ISU_SRT_CD': '008110',
#   'ISU_ABBRV': '대동전자',
#   'TDD_CLSPRC': '8,270',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '180',
#   'FLUC_RT': '2.22',
#   'MKTCAP': '86,755,996,690'},
#  {'ISU_SRT_CD': '008500',
#   'ISU_ABBRV': '일정실업',
#   'TDD_CLSPRC': '22,850',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '450',
#   'FLUC_RT': '2.01',
#   'MKTCAP': '27,420,000,000'},
#  {'ISU_SRT_CD': '008600',
#   'ISU_ABBRV': '윌비스',
#   'TDD_CLSPRC': '1,345',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '10',
#   'FLUC_RT': '0.75',
#   'MKTCAP': '90,432,472,455'},
#  {'ISU_SRT_CD': '008870',
#   'ISU_ABBRV': '금비',
#   'TDD_CLSPRC': '68,500',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '68,500,000,000'},
#  {'ISU_SRT_CD': '009140',
#   'ISU_ABBRV': '경인전자',
#   'TDD_CLSPRC': '29,650',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '300',
#   'FLUC_RT': '1.02',
#   'MKTCAP': '46,574,131,050'},
#  {'ISU_SRT_CD': '009310',
#   'ISU_ABBRV': '참엔지니어링',
#   'TDD_CLSPRC': '1,275',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '75,055,959,225'},
#  {'ISU_SRT_CD': '009770',
#   'ISU_ABBRV': '삼정펄프',
#   'TDD_CLSPRC': '30,100',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '200',
#   'FLUC_RT': '0.67',
#   'MKTCAP': '75,249,127,100'},
#  {'ISU_SRT_CD': '010100',
#   'ISU_ABBRV': '한국프랜지',
#   'TDD_CLSPRC': '3,190',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '60',
#   'FLUC_RT': '1.92',
#   'MKTCAP': '97,136,839,800'},
#  {'ISU_SRT_CD': '010400',
#   'ISU_ABBRV': '우진아이엔에스',
#   'TDD_CLSPRC': '7,650',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-30',
#   'FLUC_RT': '-0.39',
#   'MKTCAP': '58,308,300,000'},
#  {'ISU_SRT_CD': '010420',
#   'ISU_ABBRV': '한솔PNS',
#   'TDD_CLSPRC': '2,185',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-10',
#   'FLUC_RT': '-0.46',
#   'MKTCAP': '44,777,231,220'},
#  {'ISU_SRT_CD': '010640',
#   'ISU_ABBRV': '진양폴리',
#   'TDD_CLSPRC': '6,110',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-190',
#   'FLUC_RT': '-3.02',
#   'MKTCAP': '61,100,000,000'},
#  {'ISU_SRT_CD': '010660',
#   'ISU_ABBRV': '화천기계',
#   'TDD_CLSPRC': '3,295',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-20',
#   'FLUC_RT': '-0.60',
#   'MKTCAP': '72,490,000,000'},
#  {'ISU_SRT_CD': '010770',
#   'ISU_ABBRV': '평화홀딩스',
#   'TDD_CLSPRC': '3,770',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '5',
#   'FLUC_RT': '0.13',
#   'MKTCAP': '55,138,006,820'},
#  {'ISU_SRT_CD': '011230',
#   'ISU_ABBRV': '삼화전자',
#   'TDD_CLSPRC': '3,885',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-5',
#   'FLUC_RT': '-0.13',
#   'MKTCAP': '40,629,096,900'},
#  {'ISU_SRT_CD': '011300',
#   'ISU_ABBRV': '성안',
#   'TDD_CLSPRC': '655',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '51',
#   'FLUC_RT': '8.44',
#   'MKTCAP': '37,241,898,300'},
#  {'ISU_SRT_CD': '011330',
#   'ISU_ABBRV': '유니켐',
#   'TDD_CLSPRC': '1,335',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '97,039,096,770'},
#  {'ISU_SRT_CD': '011420',
#   'ISU_ABBRV': '갤럭시아에스엠',
#   'TDD_CLSPRC': '2,385',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '20',
#   'FLUC_RT': '0.85',
#   'MKTCAP': '65,705,900,940'},
#  {'ISU_SRT_CD': '012170',
#   'ISU_ABBRV': '아센디오',
#   'TDD_CLSPRC': '1,230',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-10',
#   'FLUC_RT': '-0.81',
#   'MKTCAP': '99,026,311,080'},
#  {'ISU_SRT_CD': '012280',
#   'ISU_ABBRV': '영화금속',
#   'TDD_CLSPRC': '1,735',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-5',
#   'FLUC_RT': '-0.29',
#   'MKTCAP': '92,639,466,175'},
#  {'ISU_SRT_CD': '012320',
#   'ISU_ABBRV': '경동인베스트',
#   'TDD_CLSPRC': '37,800',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-200',
#   'FLUC_RT': '-0.53',
#   'MKTCAP': '89,397,869,400'},
#  {'ISU_SRT_CD': '012600',
#   'ISU_ABBRV': '센트럴인사이트',
#   'TDD_CLSPRC': '2,490',
#   'FLUC_TP_CD': '0',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '37,500,376,080'},
#  {'ISU_SRT_CD': '013000',
#   'ISU_ABBRV': '세우글로벌',
#   'TDD_CLSPRC': '2,040',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '125',
#   'FLUC_RT': '6.53',
#   'MKTCAP': '58,558,263,240'},
#  {'ISU_SRT_CD': '013520',
#   'ISU_ABBRV': '화승코퍼레이션',
#   'TDD_CLSPRC': '1,760',
#   'FLUC_TP_CD': '3',
#   'STR_CMP_PRC': '0',
#   'FLUC_RT': '0.00',
#   'MKTCAP': '88,090,203,520'},
#  {'ISU_SRT_CD': '014130',
#   'ISU_ABBRV': '한익스프레스',
#   'TDD_CLSPRC': '5,820',
#   'FLUC_TP_CD': '2',
#   'STR_CMP_PRC': '-50',
#   'FLUC_RT': '-0.85',
#   'MKTCAP': '69,840,000,000'},
#  {'ISU_SRT_CD': '014440',
#   'ISU_ABBRV': '영보화학',
#   'TDD_CLSPRC': '4,920',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '10',
#   'FLUC_RT': '0.20',
#   'MKTCAP': '98,400,000,000'},
#  {'ISU_SRT_CD': '014910',
#   'ISU_ABBRV': '성문전자',
#   'TDD_CLSPRC': '2,405',
#   'FLUC_TP_CD': '1',
#   'STR_CMP_PRC': '15',
#   'FLUC_RT': '0.63',
#   'MKTCAP': '46,865,891,085'}]

# %% [markdown]
# * 빈 DataFrame을 만들어주고 거기에 날짜, 종목 코드, 종목 이름 등을 추가해줌
# * 모든 지수 구성 종목이 추가되었다면 그 지수가 KOSPI였음을 표시해줌
# * 모든 과정을 마쳤다면 원하는대로 데이터가 구성됐는지 확인해줌

# %%
name_hs = pd.DataFrame()

if len(html_json) > 0:
    name_h = []
